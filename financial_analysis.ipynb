# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import datetime as dt
import requests
import warnings

# catch all future warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
#finnhub_api_key = 'd399a2hr01ql85dgp6vgd399a2hr01ql85dgp700'

# %% [markdown]
# # Overview

# %%
sectors_list = [
    'basic-materials'
    ,'communication-services'
    ,'consumer-cyclical'
    ,'consumer-defensive'
    ,'energy'
    ,'financial-services'
    ,'healthcare'
    ,'industrials'
    ,'real-estate'
    ,'technology'
    ,'utilities'
]

# %%
sectors_overview = []
for sector in sectors_list:
    overview = yf.Sector(sector).overview
    overview['sector'] = yf.Sector(sector).name
    sectors_overview.append(overview)

# %%
sectors_df = pd.DataFrame(sectors_overview)

# %%
industries_list = []
for sector in sectors_list:
    industries = list(yf.Sector(sector).industries.reset_index()['key'])
    industries_list.extend(industries)

# %%
industries_overview = []
for industry in industries_list:
    overview = yf.Industry(industry).overview
    overview['industry'] = yf.Industry(industry).name
    industries_overview.append(overview)

# %%
industries_df = pd.DataFrame(industries_overview)

# %%
sector_industry = []
for sector_key in sectors_list:
    sec = yf.Sector(sector_key)
    inds = sec.industries  # DataFrame with columns like: key, name, symbol, weight

    # If a sector has no industries for some reason, skip cleanly
    if inds is None or inds.empty:
        continue

    # Use the industry "name" as the label; you could also use "key" if you prefer --> key preferred
    for industry_key in inds.index:
        sector_industry.append({
            "sector": sector_key,
            "industry": industry_key
        })

sector_industry_df = pd.DataFrame(sector_industry)
# Out:
#               sector                               industry
# 0    basic-materials                    specialty-chemicals
# 1    basic-materials                                   gold
# 2    basic-materials                     building-materials
# 3    basic-materials                                 copper
# 4    basic-materials                                  steel
# ..               ...                                    ...
# 140        utilities  utilities-independent-power-producers
# 141        utilities                utilities-regulated-gas
# 142        utilities                  utilities-diversified
# 143        utilities                    utilities-renewable
# 144        utilities              utilities-regulated-water
#
# [145 rows x 2 columns]

# %%
markets_list = [
    'US'
    ,'GB'
    ,'ASIA'
    ,'EUROPE'
    ,'RATES'
    ,'COMMODITIES'
    ,'CURRENCIES'
    ,'CRYPTOCURRENCIES'
]

# %%
markets_overview = []
for market in markets_list:
    summary = list(yf.Market(market).summary.values())
    markets_overview.extend(summary)

# %%
markets_df = pd.DataFrame(markets_overview)[['typeDisp','shortName','exchange','market','fullExchangeName','exchangeTimezoneName','symbol']]

# %%
top_companies = pd.DataFrame()
for industry in industries_list:
    companies = yf.Industry(industry).top_companies
    if companies is not None:
        companies['industry'] = industry
        top_companies = pd.concat([top_companies, companies], ignore_index=False)
    else:
        print(f"No data for industry: {industry}")
# Out:
# No data for industry: pharmaceutical-retailers
# No data for industry: infrastructure-operations

# %%
tickers = list(top_companies.index)

# %%
# get company information

def company_info(ticker, freq='yearly'):
    
    from IPython.display import display

    full_info = yf.Ticker(ticker).info
    
    # get company general info
    general_extract = ['city','state','country','industry','sector','fullTimeEmployees','website']
    general = {k: full_info[k] for k in general_extract if k in full_info}
    general_df = pd.DataFrame(general, index=[0])

    # get company officers information
    officers = full_info['companyOfficers']
    officers_df = pd.DataFrame(officers)
    officers_df = officers_df.drop('maxAge', axis=1)

    # get risk metrics
    risk_metrics = ['auditRisk','boardRisk','compensationRisk','shareHolderRightsRisk','overallRisk']
    risk = {k: full_info[k] for k in risk_metrics if k in full_info}
    risk_df = pd.DataFrame(risk, index=['Value']).T

    # get targeted KPIs
    trailing_is = yf.Ticker(ticker).get_income_stmt(freq='trailing', pretty=False, as_dict=False)
    yearly_is = yf.Ticker(ticker).get_income_stmt(freq=freq, pretty=False, as_dict=False)
    trailing_cf = yf.Ticker(ticker).get_cashflow(freq='trailing', pretty=False, as_dict=False)
    yearly_cf = yf.Ticker(ticker).get_cashflow(freq=freq, pretty=False, as_dict=False)
    
    if freq == 'yearly':
        income_st_df = trailing_is.loc[['GrossProfit', 'TotalRevenue']].join(yearly_is.loc[['GrossProfit', 'TotalRevenue']])
        cash_flow_df = trailing_cf.loc[['FreeCashFlow']].join(yearly_cf.loc[['FreeCashFlow']])
    else:
        income_st_df = yearly_is.loc[['GrossProfit', 'TotalRevenue']]
        cash_flow_df = yearly_cf.loc[['FreeCashFlow']]
    
    kpi_df = pd.concat([income_st_df, cash_flow_df])

    # calculate percent change for the KPIs
    kpi_df = kpi_df[sorted(kpi_df.columns)]
    growth = kpi_df.T.pct_change().T * 100
    kpi_df = kpi_df[sorted(kpi_df.columns, reverse=True)]
    growth = growth[sorted(growth.columns, reverse=True)]

    # function to format large numbers
    def format_large(x):
        if pd.isna(x):
            return ""
        elif abs(x) >= 1e9:
            return f"{x/1e9:.1f}B"
        elif abs(x) >= 1e6:
            return f"{x/1e6:.1f}M"
        else:
            return f"{x:.0f}"
    
    kpi_df = kpi_df.map(format_large)

    # format growth percentages
    growth = growth.map(lambda x: f"{x:.1f}%" if pd.notna(x) else "")

    display(general_df)
    display(officers_df)
    display(risk_df)
    display(kpi_df)
    display(growth)

# %%
# get targeted metrics

def target_metrics(ticker):
    t = yf.Ticker(ticker)
    
    income_statement = t.get_income_stmt(freq='quarterly', pretty=False, as_dict=False)
    cash_flow = t.get_cashflow(freq='quarterly', pretty=False, as_dict=False)

    # Safe lookup: keep only rows that exist
    income_keys = ['GrossProfit', 'TotalRevenue']
    cashflow_keys = ['FreeCashFlow']

    available_income = [k for k in income_keys if k in income_statement.index]
    available_cashflow = [k for k in cashflow_keys if k in cash_flow.index]

    income_st_df = income_statement.loc[available_income] if available_income else pd.DataFrame()
    cash_flow_df = cash_flow.loc[available_cashflow] if available_cashflow else pd.DataFrame()

    joined_df = pd.concat([income_st_df, cash_flow_df])

    if joined_df.empty:
        return pd.DataFrame()  # return empty if nothing found

    metrics_df = joined_df.T.reset_index(names='quarter')
    metrics_df['ticker'] = ticker

    return metrics_df

# %%
# 1. Query last quarter per ticker from SQLite

import sqlite3

def get_last_quarters(db_path):
    conn = sqlite3.connect(db_path)
    query = """
    SELECT ticker, MAX(quarter) as last_quarter
    FROM TGTMETRICS
    GROUP BY ticker
    """
    last_quarters = pd.read_sql(query, conn)
    conn.close()
    return last_quarters


# 2. Update function with SQLite integration

def update_metrics_sqlite(db_path, tickers):
    # Get last quarters already stored
    last_quarters = get_last_quarters(db_path)

    conn = sqlite3.connect(db_path)

    for ticker in tickers:
        # Latest known quarter in DB
        last_q = last_quarters.loc[
            last_quarters['ticker'] == ticker, 'last_quarter'
        ]
        last_q = last_q.iloc[0] if not last_q.empty else None

        # Get full Yahoo data
        metrics = target_metrics(ticker)
        if metrics.empty:
            continue

        # Keep only new quarters
        if last_q:
            new_rows = metrics[metrics['quarter'] > last_q]
        else:
            new_rows = metrics  # nothing stored yet

        if not new_rows.empty:
            new_rows.to_sql("metrics", conn, if_exists="append", index=False)
            print(f"{ticker}: added {len(new_rows)} new rows")
        #else:
        #    print(f"{ticker}: no new data")

    conn.close()

# %%
#########################################################
##########         FIRST TIME ONLY !!!         ##########
#########################################################
'''
ticker_df = pd.DataFrame()
for ticker in tickers:
    metrics = target_metrics(ticker)
    ticker_df = pd.concat([ticker_df, metrics], ignore_index=True)
'''
#########################################################
#########################################################

db_path = "financial_analytics.db"
new_ticker_df = update_metrics_sqlite(db_path, tickers)
# Out:
# LIN: added 1 new rows
# SHW: added 1 new rows
# ECL: added 1 new rows
# APD: added 1 new rows
# PPG: added 1 new rows
# IFF: added 1 new rows
# DD: added 1 new rows
# LYB: added 1 new rows
# ALB: added 1 new rows
# RPM: added 1 new rows
# WLK: added 1 new rows
# SOLS: added 3 new rows
# NEU: added 1 new rows
# EMN: added 1 new rows
# AXTA: added 1 new rows
# ESI: added 1 new rows
# BCPC: added 1 new rows
# SXT: added 1 new rows
# PRM: added 1 new rows
# CBT: added 1 new rows
# AVNT: added 1 new rows
# HWKN: added 1 new rows
# WDFC: added 1 new rows
# ASH: added 1 new rows
# KWR: added 1 new rows
# CC: added 1 new rows
# NGVT: added 1 new rows
# IOSP: added 1 new rows
# MTX: added 1 new rows
# CLMT: added 1 new rows
# ECVT: added 1 new rows
# SCL: added 1 new rows
# MATV: added 1 new rows
# KOP: added 1 new rows
# KRO: added 1 new rows
# HDSN: added 1 new rows
# OEC: added 1 new rows
# CMT: added 1 new rows
# FSI: added 1 new rows
# NTIC: added 1 new rows
# NEM: added 1 new rows
# AU: added 1 new rows
# RGLD: added 1 new rows
# CDE: added 1 new rows
# SA: added 1 new rows
# HYMC: added 1 new rows
# IDR: added 1 new rows
# CMCL: added 1 new rows
# CTGO: added 1 new rows
# CRH: added 1 new rows
# VMC: added 1 new rows
# MLM: added 1 new rows
# JHX: added 1 new rows
# EXP: added 1 new rows
# KNF: added 1 new rows
# USLM: added 1 new rows
# TTAM: added 1 new rows
# TGLS: added 1 new rows
# SMID: added 1 new rows
# SCCO: added 1 new rows
# FCX: added 1 new rows
# IE: added 1 new rows
# NUE: added 1 new rows
# STLD: added 1 new rows
# RS: added 1 new rows
# CLF: added 1 new rows
# CMC: added 1 new rows
# MTUS: added 1 new rows
# NWPX: added 1 new rows
# ZEUS: added 1 new rows
# FRD: added 1 new rows
# CTVA: added 1 new rows
# CF: added 1 new rows
# MOS: added 1 new rows
# SMG: added 1 new rows
# FMC: added 1 new rows
# UAN: added 1 new rows
# IPI: added 1 new rows
# MP: added 1 new rows
# TMC: added 1 new rows
# MTRN: added 1 new rows
# USAR: added 1 new rows
# NEXA: added 7 new rows
# UAMY: added 1 new rows
# NB: added 1 new rows
# USGO: added 1 new rows
# DOW: added 1 new rows
# CE: added 1 new rows
# OLN: added 1 new rows
# HUN: added 1 new rows
# GPRE: added 1 new rows
# ASPI: added 1 new rows
# WLKP: added 1 new rows
# LXU: added 1 new rows
# RYAM: added 1 new rows
# ASIX: added 1 new rows
# VHI: added 1 new rows
# ACNT: added 1 new rows
# HL: added 1 new rows
# MUX: added 1 new rows
# SSD: added 1 new rows
# UFPI: added 1 new rows
# BCC: added 1 new rows
# AA: added 1 new rows
# CENX: added 1 new rows
# CSTM: added 1 new rows
# KALU: added 1 new rows
# EXK: added 1 new rows
# HCC: added 1 new rows
# AMR: added 1 new rows
# METC: added 1 new rows
# SXC: added 1 new rows
# SLVM: added 1 new rows
# MAGN: added 1 new rows
# CLW: added 1 new rows
# GOOG: added 1 new rows
# META: added 1 new rows
# SPOT: added 1 new rows
# RDDT: added 1 new rows
# NBIS: added 1 new rows
# ZG: added 1 new rows
# PINS: added 1 new rows
# SNAP: added 1 new rows
# MTCH: added 1 new rows
# STUB: added 1 new rows
# DJT: added 1 new rows
# IAC: added 1 new rows
# UPWK: added 1 new rows
# GENI: added 1 new rows
# RUM: added 1 new rows
# YELP: added 1 new rows
# WBTN: added 1 new rows
# NRDS: added 1 new rows
# EVER: added 1 new rows
# MAX: added 1 new rows
# FVRR: added 1 new rows
# SSTK: added 1 new rows
# CARS: added 1 new rows
# GRPN: added 1 new rows
# ANGI: added 1 new rows
# THRY: added 1 new rows
# SEAT: added 1 new rows
# IZEA: added 7 new rows
# TZOO: added 1 new rows
# BODI: added 1 new rows
# SCOR: added 1 new rows
# TMUS: added 1 new rows
# T: added 1 new rows
# VZ: added 1 new rows
# CMCSA: added 1 new rows
# CHTR: added 1 new rows
# SATS: added 1 new rows
# FYBR: added 1 new rows
# TIGO: added 1 new rows
# LUMN: added 1 new rows
# GSAT: added 1 new rows
# LBRDA: added 1 new rows
# TDS: added 1 new rows
# AD: added 1 new rows
# LBTYA: added 1 new rows
# KYIV: added 1 new rows
# LILA: added 1 new rows
# IRDM: added 1 new rows
# GLIBA: added 1 new rows
# GOGO: added 1 new rows
# CCOI: added 1 new rows
# CABO: added 1 new rows
# SHEN: added 1 new rows
# WOW: added 1 new rows
# ATEX: added 1 new rows
# ATNI: added 1 new rows
# RDCM: added 1 new rows
# CXDO: added 1 new rows
# KVHI: added 1 new rows
# NUVR: added 1 new rows
# ELWT: added 4 new rows
# NFLX: added 1 new rows
# DIS: added 1 new rows
# WBD: added 1 new rows
# LYV: added 1 new rows
# FOXA: added 1 new rows
# FWONA: added 1 new rows
# TKO: added 1 new rows
# NWSA: added 1 new rows
# WMG: added 1 new rows
# ROKU: added 1 new rows
# SIRI: added 1 new rows
# MSGS: added 1 new rows
# CNK: added 1 new rows
# SPHR: added 1 new rows
# BATRA: added 1 new rows
# LION: added 1 new rows
# IMAX: added 1 new rows
# AENT: added 1 new rows
# RSVR: added 1 new rows
# MCS: added 1 new rows
# AMCX: added 1 new rows
# STRZ: added 1 new rows
# APP: added 1 new rows
# OMC: added 1 new rows
# TTD: added 1 new rows
# IPG: added 1 new rows
# MGNI: added 1 new rows
# IAS: added 1 new rows
# DV: added 7 new rows
# STGW: added 1 new rows
# ZD: added 1 new rows
# QNST: added 1 new rows
# ACCS: added 1 new rows
# RBLX: added 1 new rows
# EA: added 1 new rows
# TTWO: added 1 new rows
# SKLZ: added 1 new rows
# NYT: added 1 new rows
# TDAY: added 7 new rows
# NXST: added 1 new rows
# TGNA: added 1 new rows
# SBGI: added 1 new rows
# NMAX: added 1 new rows
# GTN-A: added 1 new rows
# SGA: added 1 new rows
# AMZN: added 1 new rows
# MELI: added 1 new rows
# DASH: added 1 new rows
# CPNG: added 1 new rows
# EBAY: added 1 new rows
# W: added 1 new rows
# CART: added 1 new rows
# GLBE: added 1 new rows
# ETSY: added 1 new rows
# RVLV: added 1 new rows
# TDUP: added 1 new rows
# LQDT: added 1 new rows
# BBBY: added 1 new rows
# DIBS: added 7 new rows
# LOGC: added 2 new rows
# QVCGA: added 1 new rows
# SBDS: added 1 new rows
# IPW: added 6 new rows
# TSLA: added 1 new rows
# GM: added 1 new rows
# F: added 1 new rows
# RIVN: added 1 new rows
# LCID: added 1 new rows
# EMPD: added 1 new rows
# SEV: added 3 new rows
# SSM: added 1 new rows
# MCD: added 1 new rows
# SBUX: added 1 new rows
# CMG: added 1 new rows
# YUM: added 1 new rows
# YUMC: added 1 new rows
# DPZ: added 1 new rows
# TXRH: added 1 new rows
# BROS: added 1 new rows
# WING: added 1 new rows
# EAT: added 1 new rows
# CAVA: added 1 new rows
# SHAK: added 1 new rows
# CAKE: added 1 new rows
# WEN: added 1 new rows
# ARCO: added 1 new rows
# PZZA: added 1 new rows
# FWRG: added 1 new rows
# BH: added 1 new rows
# BJRI: added 1 new rows
# CNNE: added 1 new rows
# SG: added 1 new rows
# BLMN: added 1 new rows
# KRUS: added 1 new rows
# DIN: added 1 new rows
# VENU: added 1 new rows
# BRCB: added 3 new rows
# NATH: added 1 new rows
# PTLO: added 1 new rows
# JACK: added 1 new rows
# LOCO: added 1 new rows
# DENN: added 1 new rows
# HD: added 1 new rows
# LOW: added 1 new rows
# FND: added 1 new rows
# HVT: added 1 new rows
# TTSH: added 1 new rows
# BKNG: added 1 new rows
# RCL: added 1 new rows
# ABNB: added 1 new rows
# EXPE: added 1 new rows
# VIK: added 1 new rows
# NCLH: added 1 new rows
# MMYT: added 1 new rows
# TNL: added 1 new rows
# GBTG: added 1 new rows
# TRIP: added 1 new rows
# LIND: added 1 new rows
# NUTR: added 1 new rows
# ORLY: added 1 new rows
# GPC: added 1 new rows
# APTV: added 1 new rows
# MBLY: added 1 new rows
# BWA: added 1 new rows
# ALV: added 1 new rows
# MOD: added 1 new rows
# LKQ: added 1 new rows
# ALSN: added 1 new rows
# QS: added 1 new rows
# LEA: added 1 new rows
# GNTX: added 1 new rows
# ATMU: added 1 new rows
# DORM: added 1 new rows
# GTX: added 1 new rows
# AAP: added 1 new rows
# DAN: added 1 new rows
# VC: added 1 new rows
# GT: added 1 new rows
# PHIN: added 1 new rows
# ADNT: added 1 new rows
# XPEL: added 1 new rows
# THRM: added 1 new rows
# SLDP: added 7 new rows
# SMP: added 1 new rows
# AXL: added 1 new rows
# PLOW: added 1 new rows
# FOXF: added 1 new rows
# MNRO: added 1 new rows
# CPS: added 1 new rows
# MLR: added 1 new rows
# STRT: added 1 new rows
# MPAA: added 1 new rows
# SRI: added 1 new rows
# TJX: added 1 new rows
# ROST: added 1 new rows
# BURL: added 1 new rows
# GAP: added 1 new rows
# URBN: added 1 new rows
# BOOT: added 1 new rows
# ANF: added 1 new rows
# BKE: added 1 new rows
# CRI: added 1 new rows
# GES: added 1 new rows
# SCVL: added 1 new rows
# AKA: added 1 new rows
# DBGI: added 1 new rows
# BIRD: added 1 new rows
# LVLU: added 7 new rows
# DHI: added 1 new rows
# PHM: added 1 new rows
# NVR: added 1 new rows
# IBP: added 1 new rows
# TMHC: added 1 new rows
# MTH: added 1 new rows
# SKY: added 1 new rows
# CVCO: added 1 new rows
# MHO: added 1 new rows
# TPH: added 1 new rows
# GRBK: added 1 new rows
# DFH: added 1 new rows
# LGIH: added 1 new rows
# BZH: added 1 new rows
# LEGH: added 1 new rows
# TSCO: added 1 new rows
# WSM: added 1 new rows
# DKS: added 1 new rows
# BBY: added 1 new rows
# MUSA: added 1 new rows
# BBWI: added 1 new rows
# EYE: added 1 new rows
# SBH: added 1 new rows
# WINA: added 1 new rows
# ARHS: added 1 new rows
# SVV: added 1 new rows
# ODP: added 1 new rows
# BWMX: added 1 new rows
# HZO: added 1 new rows
# ONEW: added 1 new rows
# MAR: added 1 new rows
# HLT: added 1 new rows
# H: added 1 new rows
# WH: added 1 new rows
# CHH: added 1 new rows
# SHCO: added 1 new rows
# CVEO: added 1 new rows
# INTG: added 2 new rows
# IP: added 1 new rows
# AMCR: added 1 new rows
# SW: added 1 new rows
# PKG: added 1 new rows
# BALL: added 1 new rows
# AVY: added 1 new rows
# CCK: added 1 new rows
# SEE: added 1 new rows
# REYN: added 1 new rows
# GPK: added 1 new rows
# SLGN: added 1 new rows
# SON: added 1 new rows
# OI: added 1 new rows
# TRS: added 1 new rows
# MYE: added 1 new rows
# KRT: added 1 new rows
# CVNA: added 1 new rows
# PAG: added 1 new rows
# LAD: added 1 new rows
# AN: added 1 new rows
# GPI: added 1 new rows
# ABG: added 1 new rows
# RUSHA: added 1 new rows
# VVV: added 1 new rows
# CARG: added 1 new rows
# KAR: added 1 new rows
# DRVN: added 1 new rows
# SAH: added 1 new rows
# MCW: added 1 new rows
# ACVA: added 1 new rows
# CWH: added 1 new rows
# KFS: added 1 new rows
# RDNW: added 6 new rows
# NKE: added 1 new rows
# ONON: added 1 new rows
# DECK: added 1 new rows
# CROX: added 1 new rows
# SHOO: added 1 new rows
# WWW: added 1 new rows
# WEYS: added 1 new rows
# RCKY: added 1 new rows
# LVS: added 1 new rows
# WYNN: added 1 new rows
# MGM: added 1 new rows
# BYD: added 1 new rows
# RRR: added 1 new rows
# CZR: added 1 new rows
# HGV: added 1 new rows
# PENN: added 1 new rows
# VAC: added 1 new rows
# MCRI: added 1 new rows
# BALY: added 1 new rows
# GDEN: added 1 new rows
# CPHC: added 1 new rows
# FLUT: added 1 new rows
# DKNG: added 1 new rows
# CHDN: added 1 new rows
# LNW: added 1 new rows
# SGHC: added 1 new rows
# RSI: added 1 new rows
# BRSL: added 1 new rows
# SBET: added 1 new rows
# ACEL: added 1 new rows
# INSE: added 1 new rows
# GAMB: added 1 new rows
# AS: added 1 new rows
# HAS: added 1 new rows
# PLNT: added 1 new rows
# MAT: added 1 new rows
# LTH: added 1 new rows
# GOLF: added 1 new rows
# YETI: added 1 new rows
# PTON: added 1 new rows
# MODG: added 1 new rows
# MSGE: added 1 new rows
# OSW: added 1 new rows
# PRKS: added 1 new rows
# FUN: added 1 new rows
# LUCK: added 1 new rows
# XPOF: added 1 new rows
# JAKK: added 1 new rows
# ESCA: added 1 new rows
# NOMA: added 6 new rows
# LEAT: added 1 new rows
# RL: added 1 new rows
# LEVI: added 1 new rows
# VFC: added 1 new rows
# KTB: added 1 new rows
# COLM: added 1 new rows
# HBI: added 1 new rows
# FIGS: added 1 new rows
# SGC: added 1 new rows
# SGI: added 1 new rows
# SN: added 1 new rows
# MHK: added 1 new rows
# ALH: added 3 new rows
# WHR: added 1 new rows
# PATK: added 1 new rows
# HNI: added 1 new rows
# TILE: added 1 new rows
# LZB: added 1 new rows
# MBC: added 1 new rows
# LEG: added 1 new rows
# AMWD: added 1 new rows
# ETD: added 1 new rows
# XWIN: added 7 new rows
# HBB: added 1 new rows
# FLXS: added 1 new rows
# NVFY: added 1 new rows
# BSET: added 1 new rows
# SNBR: added 1 new rows
# FGI: added 1 new rows
# ROL: added 1 new rows
# SCI: added 1 new rows
# BFAM: added 1 new rows
# HRB: added 1 new rows
# FTDR: added 1 new rows
# CSV: added 1 new rows
# WW: added 1 new rows
# MED: added 1 new rows
# RGS: added 1 new rows
# TPR: added 1 new rows
# CPRI: added 1 new rows
# REAL: added 1 new rows
# MOV: added 1 new rows
# ELA: added 1 new rows
# BC: added 1 new rows
# PII: added 1 new rows
# HOG: added 1 new rows
# LCII: added 1 new rows
# WGO: added 1 new rows
# MBUU: added 1 new rows
# MCFT: added 1 new rows
# MPX: added 1 new rows
# DDS: added 1 new rows
# KSS: added 1 new rows
# AIN: added 1 new rows
# WMT: added 1 new rows
# TGT: added 1 new rows
# BJ: added 1 new rows
# PSMT: added 1 new rows
# TBBB: added 1 new rows
# KO: added 1 new rows
# PEP: added 1 new rows
# MNST: added 1 new rows
# KDP: added 1 new rows
# COKE: added 1 new rows
# CELH: added 1 new rows
# PRMB: added 1 new rows
# COCO: added 1 new rows
# REEDD: added 7 new rows
# PG: added 1 new rows
# CL: added 1 new rows
# KMB: added 1 new rows
# EL: added 1 new rows
# KVUE: added 1 new rows
# CHD: added 1 new rows
# CLX: added 1 new rows
# ELF: added 1 new rows
# IPAR: added 1 new rows
# ODD: added 7 new rows
# SPB: added 1 new rows
# EPC: added 1 new rows
# NUS: added 1 new rows
# HELE: added 1 new rows
# ACU: added 1 new rows
# UG: added 1 new rows
# PM: added 1 new rows
# MO: added 1 new rows
# TPB: added 1 new rows
# UVV: added 1 new rows
# RYM: added 1 new rows
# KHC: added 1 new rows
# K: added 1 new rows
# MKC: added 1 new rows
# JBS: added 1 new rows
# SJM: added 1 new rows
# PPC: added 1 new rows
# CAG: added 1 new rows
# SFD: added 1 new rows
# LW: added 1 new rows
# INGR: added 1 new rows
# DAR: added 1 new rows
# POST: added 1 new rows
# MZTI: added 1 new rows
# BRBR: added 1 new rows
# FRPT: added 1 new rows
# FLO: added 1 new rows
# CENT: added 1 new rows
# SMPL: added 1 new rows
# NOMD: added 1 new rows
# JJSF: added 1 new rows
# HLF: added 1 new rows
# THS: added 1 new rows
# UTZ: added 1 new rows
# JBSS: added 1 new rows
# SENEA: added 1 new rows
# LWAY: added 1 new rows
# NATR: added 1 new rows
# USNA: added 1 new rows
# FTLF: added 1 new rows
# BHST: added 1 new rows
# CLNN: added 1 new rows
# LFVN: added 1 new rows
# MDLZ: added 1 new rows
# HSY: added 1 new rows
# TR: added 1 new rows
# ADM: added 1 new rows
# TSN: added 1 new rows
# BG: added 1 new rows
# CALM: added 1 new rows
# FDP: added 1 new rows
# VITL: added 1 new rows
# DOLE: added 1 new rows
# AGRO: added 1 new rows
# ALCO: added 1 new rows
# SYY: added 1 new rows
# USFD: added 1 new rows
# PFGC: added 1 new rows
# CHEF: added 1 new rows
# UNFI: added 1 new rows
# ANDE: added 1 new rows
# WILC: added 1 new rows
# DIT: added 1 new rows
# MTEX: added 1 new rows
# ACI: added 1 new rows
# SFM: added 1 new rows
# WMK: added 1 new rows
# IMKTA: added 1 new rows
# GO: added 1 new rows
# NGVC: added 1 new rows
# GHC: added 1 new rows
# LAUR: added 1 new rows
# LOPE: added 1 new rows
# ATGE: added 1 new rows
# MH: added 1 new rows
# LRN: added 1 new rows
# STRA: added 1 new rows
# PRDO: added 1 new rows
# AFYA: added 1 new rows
# COUR: added 1 new rows
# UTI: added 1 new rows
# PXED: added 2 new rows
# UDMY: added 1 new rows
# LINC: added 1 new rows
# APEI: added 1 new rows
# FC: added 1 new rows
# LGCY: added 1 new rows
# STZ: added 1 new rows
# TAP: added 1 new rows
# SAM: added 1 new rows
# MGPI: added 1 new rows
# CWGL: added 1 new rows
# IPST: added 7 new rows
# XOM: added 1 new rows
# CVX: added 1 new rows
# NFG: added 1 new rows
# UNTC: added 1 new rows
# WMB: added 1 new rows
# EPD: added 1 new rows
# KMI: added 1 new rows
# ET: added 1 new rows
# MPLX: added 1 new rows
# OKE: added 1 new rows
# LNG: added 1 new rows
# TRGP: added 1 new rows
# CQP: added 1 new rows
# VG: added 1 new rows
# WES: added 1 new rows
# DTM: added 1 new rows
# PAA: added 1 new rows
# VNOM: added 1 new rows
# AM: added 1 new rows
# HESM: added 1 new rows
# FRO: added 1 new rows
# PAGP: added 1 new rows
# GLNG: added 1 new rows
# EE: added 1 new rows
# STNG: added 1 new rows
# INSW: added 1 new rows
# KNTK: added 1 new rows
# DHT: added 1 new rows
# TNK: added 1 new rows
# GEL: added 1 new rows
# GLP: added 1 new rows
# FLNG: added 6 new rows
# NGL: added 1 new rows
# NVGS: added 1 new rows
# SBR: added 1 new rows
# LPG: added 1 new rows
# PBT: added 1 new rows
# TEN: added 2 new rows
# SMC: added 1 new rows
# COP: added 1 new rows
# EOG: added 1 new rows
# FANG: added 1 new rows
# OXY: added 1 new rows
# EQT: added 1 new rows
# EXE: added 1 new rows
# DVN: added 1 new rows
# CTRA: added 1 new rows
# TPL: added 1 new rows
# PR: added 1 new rows
# AR: added 1 new rows
# OVV: added 1 new rows
# RRC: added 1 new rows
# APA: added 1 new rows
# CRK: added 1 new rows
# CNX: added 1 new rows
# CHRD: added 1 new rows
# MTDR: added 1 new rows
# MUR: added 1 new rows
# MGY: added 1 new rows
# GPOR: added 1 new rows
# CRC: added 1 new rows
# BSM: added 1 new rows
# CIVI: added 1 new rows
# BKV: added 1 new rows
# CRGY: added 1 new rows
# SM: added 1 new rows
# NOG: added 1 new rows
# TALO: added 1 new rows
# MNR: added 1 new rows
# KRP: added 1 new rows
# DMLP: added 1 new rows
# HPK: added 1 new rows
# VTS: added 1 new rows
# VTLE: added 1 new rows
# TXO: added 1 new rows
# GRNT: added 1 new rows
# REPX: added 1 new rows
# SD: added 1 new rows
# TBN: added 1 new rows
# GPRK: added 1 new rows
# PNRG: added 1 new rows
# SJT: added 1 new rows
# AMPY: added 1 new rows
# INR: added 1 new rows
# CRT: added 1 new rows
# CKX: added 7 new rows
# MXC: added 7 new rows
# SLB: added 1 new rows
# BKR: added 1 new rows
# HAL: added 1 new rows
# FTI: added 1 new rows
# NOV: added 1 new rows
# WFRD: added 1 new rows
# LB: added 1 new rows
# AROC: added 1 new rows
# VAL: added 1 new rows
# SEI: added 1 new rows
# USAC: added 1 new rows
# KGS: added 1 new rows
# WHD: added 1 new rows
# LBRT: added 1 new rows
# TDW: added 1 new rows
# OII: added 1 new rows
# NEXT: added 1 new rows
# XPRO: added 1 new rows
# FLOC: added 1 new rows
# AESI: added 1 new rows
# NESR: added 1 new rows
# WTTR: added 1 new rows
# RES: added 7 new rows
# MRC: added 1 new rows
# VTOL: added 1 new rows
# PUMP: added 1 new rows
# WBI: added 1 new rows
# HLX: added 1 new rows
# CLB: added 1 new rows
# FTK: added 1 new rows
# NGS: added 1 new rows
# OIS: added 1 new rows
# FET: added 1 new rows
# RNGR: added 1 new rows
# GEOS: added 1 new rows
# NCSM: added 1 new rows
# MPC: added 1 new rows
# PSX: added 1 new rows
# VLO: added 1 new rows
# SUN: added 1 new rows
# DINO: added 1 new rows
# IEP: added 1 new rows
# PBF: added 1 new rows
# CVI: added 1 new rows
# DKL: added 1 new rows
# DK: added 1 new rows
# PARR: added 1 new rows
# WKC: added 1 new rows
# CAPL: added 1 new rows
# LEU: added 1 new rows
# NE: added 1 new rows
# HP: added 1 new rows
# PTEN: added 1 new rows
# SDRL: added 1 new rows
# NBR: added 1 new rows
# CNR: added 1 new rows
# BTU: added 1 new rows
# ARLP: added 1 new rows
# NRP: added 1 new rows
# HNRG: added 1 new rows
# NC: added 1 new rows
# JPM: added 1 new rows
# BAC: added 1 new rows
# WFC: added 1 new rows
# C: added 1 new rows
# BK: added 1 new rows
# NTB: added 1 new rows
# V: added 1 new rows
# MA: added 1 new rows
# AXP: added 1 new rows
# COF: added 1 new rows
# PYPL: added 1 new rows
# SOFI: added 1 new rows
# SYF: added 1 new rows
# ALLY: added 1 new rows
# OMF: added 1 new rows
# FCFS: added 1 new rows
# SLM: added 1 new rows
# CACC: added 1 new rows
# NNI: added 1 new rows
# UPST: added 1 new rows
# ENVA: added 1 new rows
# BFH: added 1 new rows
# WU: added 1 new rows
# SEZL: added 1 new rows
# AGM-A: added 1 new rows
# NAVI: added 1 new rows
# JCAP: added 1 new rows
# ECPG: added 1 new rows
# EZPW: added 1 new rows
# ATLC: added 1 new rows
# OPFI: added 1 new rows
# WRLD: added 1 new rows
# GDOT: added 1 new rows
# PRAA: added 1 new rows
# RM: added 1 new rows
# MFIN: added 1 new rows
# ANTA: added 1 new rows
# OPRT: added 1 new rows
# FOA: added 1 new rows
# CPSS: added 1 new rows
# PMTS: added 1 new rows
# VRM: added 1 new rows
# OMCC: added 1 new rows
# BX: added 1 new rows
# BLK: added 1 new rows
# KKR: added 1 new rows
# APO: added 1 new rows
# ARES: added 1 new rows
# AMP: added 1 new rows
# STT: added 1 new rows
# RJF: added 1 new rows
# NTRS: added 1 new rows
# OWL: added 1 new rows
# TPG: added 1 new rows
# TROW: added 1 new rows
# CG: added 1 new rows
# PFG: added 1 new rows
# CRBG: added 1 new rows
# ARCC: added 1 new rows
# EQH: added 1 new rows
# BEN: added 1 new rows
# IVZ: added 1 new rows
# PSLV: added 1 new rows
# SEIC: added 1 new rows
# STEP: added 1 new rows
# AMG: added 1 new rows
# HLNE: added 1 new rows
# JHG: added 1 new rows
# OBDC: added 1 new rows
# BXSL: added 1 new rows
# MAIN: added 1 new rows
# AB: added 1 new rows
# FSK: added 1 new rows
# HASI: added 1 new rows
# VCTR: added 1 new rows
# FHI: added 1 new rows
# GBDC: added 1 new rows
# HTGC: added 1 new rows
# CNS: added 1 new rows
# APAM: added 1 new rows
# AIG: added 1 new rows
# ACGL: added 1 new rows
# FIHL: added 1 new rows
# IGIC: added 1 new rows
# GS: added 1 new rows
# MS: added 1 new rows
# SCHW: added 1 new rows
# HOOD: added 1 new rows
# IBKR: added 1 new rows
# LPLA: added 1 new rows
# TW: added 1 new rows
# CRCL: added 1 new rows
# IREN: added 1 new rows
# BMNR: added 1 new rows
# SF: added 1 new rows
# EVR: added 1 new rows
# HLI: added 1 new rows
# JEF: added 1 new rows
# GLXY: added 1 new rows
# XP: added 1 new rows
# CIFR: added 1 new rows
# FIGR: added 1 new rows
# VIRT: added 1 new rows
# PJT: added 1 new rows
# WULF: added 1 new rows
# MKTX: added 1 new rows
# RIOT: added 1 new rows
# PIPR: added 1 new rows
# HUT: added 1 new rows
# LAZ: added 1 new rows
# MC: added 1 new rows
# SNEX: added 1 new rows
# MARA: added 1 new rows
# BGC: added 1 new rows
# CLSK: added 1 new rows
# MIAX: added 1 new rows
# ETOR: added 1 new rows
# MRX: added 1 new rows
# PWP: added 1 new rows
# GEMI: added 3 new rows
# OPY: added 1 new rows
# AMRK: added 1 new rows
# FRGE: added 1 new rows
# COHN: added 1 new rows
# MIGI: added 7 new rows
# NU: added 1 new rows
# USB: added 1 new rows
# PNC: added 1 new rows
# TFC: added 1 new rows
# MTB: added 1 new rows
# FITB: added 1 new rows
# HBAN: added 1 new rows
# FCNCA: added 1 new rows
# CFG: added 1 new rows
# RF: added 1 new rows
# BAP: added 1 new rows
# KEY: added 1 new rows
# EWBC: added 1 new rows
# FHN: added 1 new rows
# CMA: added 1 new rows
# WBS: added 1 new rows
# SSB: added 1 new rows
# WAL: added 1 new rows
# WTFC: added 1 new rows
# ONB: added 1 new rows
# UMBF: added 1 new rows
# COLB: added 1 new rows
# CFR: added 1 new rows
# ZION: added 1 new rows
# BPOP: added 1 new rows
# CADE: added 1 new rows
# CBSH: added 1 new rows
# BOKF: added 1 new rows
# PNFP: added 1 new rows
# SNV: added 1 new rows
# PB: added 1 new rows
# VLY: added 1 new rows
# FNB: added 1 new rows
# HOMB: added 1 new rows
# GBCI: added 1 new rows
# UBSI: added 1 new rows
# ABCB: added 1 new rows
# OZK: added 1 new rows
# HWC: added 1 new rows
# FLG: added 1 new rows
# AUB: added 1 new rows
# AX: added 1 new rows
# FFIN: added 1 new rows
# ASB: added 1 new rows
# EBC: added 7 new rows
# IBOC: added 1 new rows
# TCBI: added 1 new rows
# INTR: added 1 new rows
# TFSL: added 6 new rows
# SPGI: added 1 new rows
# CME: added 1 new rows
# ICE: added 1 new rows
# MCO: added 1 new rows
# COIN: added 1 new rows
# NDAQ: added 1 new rows
# MSCI: added 1 new rows
# CBOE: added 1 new rows
# TRU: added 1 new rows
# MORN: added 1 new rows
# OTCM: added 1 new rows
# MKTW: added 1 new rows
# PGR: added 1 new rows
# CB: added 1 new rows
# TRV: added 1 new rows
# ALL: added 1 new rows
# HIG: added 1 new rows
# WRB: added 1 new rows
# MKL: added 1 new rows
# CINF: added 1 new rows
# L: added 1 new rows
# CNA: added 1 new rows
# AIZ: added 1 new rows
# AFG: added 1 new rows
# ORI: added 1 new rows
# KNSL: added 1 new rows
# THG: added 1 new rows
# LMND: added 1 new rows
# RLI: added 1 new rows
# WTM: added 1 new rows
# MCY: added 1 new rows
# SIGI: added 1 new rows
# HGTY: added 1 new rows
# AHL: added 1 new rows
# PLMR: added 1 new rows
# KMPR: added 1 new rows
# HCI: added 1 new rows
# STC: added 1 new rows
# SLDE: added 1 new rows
# SKWD: added 1 new rows
# HMN: added 1 new rows
# TRUP: added 1 new rows
# ROOT: added 1 new rows
# PRA: added 1 new rows
# SAFT: added 1 new rows
# BOW: added 1 new rows
# UVE: added 1 new rows
# UFCS: added 1 new rows
# ASIC: added 1 new rows
# HRTG: added 1 new rows
# HIPO: added 1 new rows
# DGICA: added 1 new rows
# ACIC: added 1 new rows
# AII: added 1 new rows
# GBLI: added 1 new rows
# NODK: added 1 new rows
# KINS: added 1 new rows
# MMC: added 1 new rows
# AON: added 1 new rows
# AJG: added 1 new rows
# WTW: added 1 new rows
# BRO: added 1 new rows
# ERIE: added 1 new rows
# CRVL: added 1 new rows
# ARX: added 1 new rows
# NP: added 3 new rows
# GSHD: added 1 new rows
# BWIN: added 1 new rows
# CRD-A: added 1 new rows
# TWFG: added 1 new rows
# QDMI: added 7 new rows
# KG: added 1 new rows
# AFL: added 1 new rows
# MET: added 1 new rows
# PRU: added 1 new rows
# UNM: added 1 new rows
# GL: added 1 new rows
# PRI: added 1 new rows
# LNC: added 1 new rows
# JXN: added 1 new rows
# FG: added 1 new rows
# CNO: added 1 new rows
# BHF: added 1 new rows
# GNW: added 1 new rows
# ABL: added 1 new rows
# CIA: added 1 new rows
# KCLI: added 1 new rows
# FNF: added 1 new rows
# RYAN: added 1 new rows
# AXS: added 1 new rows
# FAF: added 1 new rows
# MTG: added 1 new rows
# ESNT: added 1 new rows
# ACT: added 1 new rows
# RDN: added 1 new rows
# AGO: added 1 new rows
# NMIH: added 1 new rows
# EIG: added 1 new rows
# AMSF: added 1 new rows
# TIPT: added 1 new rows
# ITIC: added 1 new rows
# AMBC: added 1 new rows
# OSG: added 7 new rows
# MBI: added 1 new rows
# JRVR: added 1 new rows
# RKT: added 1 new rows
# UWMC: added 1 new rows
# PFSI: added 1 new rows
# WD: added 1 new rows
# GHLD: added 1 new rows
# BETR: added 1 new rows
# VEL: added 1 new rows
# ONIT: added 1 new rows
# SNFCA: added 1 new rows
# GHI: added 1 new rows
# IOR: added 1 new rows
# EG: added 1 new rows
# RGA: added 1 new rows
# RNR: added 1 new rows
# HG: added 1 new rows
# SPNT: added 1 new rows
# GLRE: added 1 new rows
# FRHC: added 1 new rows
# VOYA: added 1 new rows
# HTH: added 1 new rows
# TREE: added 1 new rows
# CCCX: added 1 new rows
# CEPF: added 1 new rows
# EVAC: added 1 new rows
# BCSS: added 2 new rows
# AEXA: added 1 new rows
# GIW: added 1 new rows
# EQV: added 1 new rows
# FTW: added 6 new rows
# AAM: added 1 new rows
# GTEN: added 1 new rows
# ANSC: added 1 new rows
# BACQ: added 1 new rows
# GSRT: added 6 new rows
# MBVI: added 1 new rows
# TLNC: added 1 new rows
# BCAR: added 1 new rows
# RTAC: added 1 new rows
# KFII: added 1 new rows
# NPAC: added 3 new rows
# CRAQ: added 3 new rows
# CCIX: added 1 new rows
# PCAP: added 1 new rows
# GPAT: added 1 new rows
# TACO: added 1 new rows
# RDAG: added 1 new rows
# ALF: added 1 new rows
# MBAV: added 1 new rows
# WENN: added 1 new rows
# CAEP: added 1 new rows
# CCII: added 1 new rows
# TACH: added 1 new rows
# BDCI: added 7 new rows
# CGCT: added 3 new rows
# GIG: added 1 new rows
# IPCX: added 1 new rows
# KCHV: added 1 new rows
# OTGA: added 1 new rows
# BLZR: added 1 new rows
# DMAA: added 1 new rows
# BRR: added 1 new rows
# SOUL: added 1 new rows
# CHAC: added 3 new rows
# HCMA: added 1 new rows
# AXIN: added 1 new rows
# LLY: added 1 new rows
# JNJ: added 1 new rows
# ABBV: added 1 new rows
# MRK: added 1 new rows
# AMGN: added 1 new rows
# GILD: added 1 new rows
# PFE: added 1 new rows
# BMY: added 1 new rows
# BIIB: added 1 new rows
# OGN: added 1 new rows
# SCLX: added 1 new rows
# VRTX: added 1 new rows
# REGN: added 1 new rows
# ALNY: added 1 new rows
# INSM: added 1 new rows
# RPRX: added 1 new rows
# INCY: added 1 new rows
# RVMD: added 1 new rows
# ROIV: added 1 new rows
# BBIO: added 1 new rows
# MDGL: added 1 new rows
# IONS: added 1 new rows
# SMMT: added 1 new rows
# EXEL: added 1 new rows
# RNA: added 1 new rows
# BMRN: added 1 new rows
# JAZZ: added 1 new rows
# MRNA: added 1 new rows
# TECH: added 1 new rows
# NUVL: added 1 new rows
# HALO: added 1 new rows
# CORT: added 1 new rows
# CYTK: added 1 new rows
# AXSM: added 1 new rows
# ARWR: added 1 new rows
# RYTM: added 1 new rows
# CAI: added 1 new rows
# CDTX: added 7 new rows
# PTCT: added 1 new rows
# PCVX: added 1 new rows
# KRYS: added 1 new rows
# COGT: added 7 new rows
# PTGX: added 1 new rows
# TGTX: added 1 new rows
# CRSP: added 1 new rows
# APGE: added 7 new rows
# PRAX: added 5 new rows
# KYMR: added 1 new rows
# NAMS: added 1 new rows
# CELC: added 7 new rows
# ADMA: added 1 new rows
# SRRK: added 1 new rows
# AKRO: added 1 new rows
# CRNX: added 1 new rows
# ACAD: added 1 new rows
# IMVT: added 7 new rows
# ACLX: added 1 new rows
# VKTX: added 7 new rows
# LGND: added 1 new rows
# ABT: added 1 new rows
# BSX: added 1 new rows
# SYK: added 1 new rows
# MDT: added 1 new rows
# EW: added 1 new rows
# STE: added 1 new rows
# DXCM: added 1 new rows
# PODD: added 1 new rows
# ZBH: added 1 new rows
# GMED: added 1 new rows
# PEN: added 1 new rows
# BIO: added 1 new rows
# MASI: added 1 new rows
# BRKR: added 1 new rows
# GKOS: added 1 new rows
# IRTC: added 1 new rows
# TMDX: added 1 new rows
# HAE: added 1 new rows
# INSP: added 1 new rows
# LIVN: added 1 new rows
# ATEC: added 1 new rows
# ITGR: added 1 new rows
# AORT: added 1 new rows
# ESTA: added 1 new rows
# QDEL: added 1 new rows
# PRCT: added 1 new rows
# UFPT: added 1 new rows
# ENOV: added 1 new rows
# NVCR: added 1 new rows
# TNDM: added 1 new rows
# BBNX: added 1 new rows
# CNMD: added 1 new rows
# AXGN: added 1 new rows
# AHCO: added 1 new rows
# SSII: added 1 new rows
# IRMD: added 1 new rows
# IART: added 1 new rows
# INMD: added 1 new rows
# SIBN: added 1 new rows
# CTKB: added 7 new rows
# OFIX: added 1 new rows
# CBLL: added 7 new rows
# SRDX: added 6 new rows
# TCMD: added 7 new rows
# AVNS: added 1 new rows
# NPCE: added 7 new rows
# BVS: added 1 new rows
# VREX: added 1 new rows
# RXST: added 7 new rows
# TMO: added 1 new rows
# DHR: added 1 new rows
# IDXX: added 1 new rows
# A: added 1 new rows
# IQV: added 1 new rows
# NTRA: added 1 new rows
# MTD: added 1 new rows
# WAT: added 1 new rows
# LH: added 1 new rows
# DGX: added 1 new rows
# ILMN: added 1 new rows
# EXAS: added 1 new rows
# MEDP: added 1 new rows
# ICLR: added 1 new rows
# GH: added 1 new rows
# RVTY: added 1 new rows
# QGEN: added 1 new rows
# CRL: added 1 new rows
# RDNT: added 1 new rows
# SHC: added 1 new rows
# WGS: added 1 new rows
# GRAL: added 1 new rows
# VCYT: added 1 new rows
# TWST: added 1 new rows
# NEO: added 1 new rows
# NEOG: added 1 new rows
# CSTL: added 1 new rows
# PSNL: added 1 new rows
# CDNA: added 1 new rows
# FLGT: added 1 new rows
# MYGN: added 1 new rows
# PRE: added 1 new rows
# XGN: added 1 new rows
# IMDX: added 7 new rows
# FONR: added 1 new rows
# BDSX: added 1 new rows
# PRPO: added 1 new rows
# APDN: added 6 new rows
# NDRA: added 1 new rows
# UNH: added 1 new rows
# CVS: added 1 new rows
# ELV: added 1 new rows
# CI: added 1 new rows
# HUM: added 1 new rows
# CNC: added 1 new rows
# MOH: added 1 new rows
# OSCR: added 1 new rows
# ALHC: added 1 new rows
# PGNY: added 1 new rows
# ISRG: added 1 new rows
# BDX: added 1 new rows
# RMD: added 1 new rows
# WST: added 1 new rows
# HOLX: added 1 new rows
# SOLV: added 1 new rows
# ALGN: added 1 new rows
# BAX: added 1 new rows
# RGEN: added 1 new rows
# ATR: added 1 new rows
# AVTR: added 1 new rows
# STVN: added 1 new rows
# MMSI: added 1 new rows
# TFX: added 1 new rows
# ICUI: added 1 new rows
# NVST: added 1 new rows
# WRBY: added 1 new rows
# XRAY: added 1 new rows
# LMAT: added 1 new rows
# ATRC: added 1 new rows
# AZTA: added 1 new rows
# STAA: added 1 new rows
# BLFS: added 1 new rows
# PLSE: added 1 new rows
# EMBC: added 1 new rows
# ANGO: added 1 new rows
# KRMD: added 7 new rows
# INFU: added 1 new rows
# SMTI: added 1 new rows
# UTMD: added 1 new rows
# PDEX: added 1 new rows
# GCTK: added 1 new rows
# MCK: added 1 new rows
# COR: added 1 new rows
# CAH: added 1 new rows
# HSIC: added 1 new rows
# HCA: added 1 new rows
# THC: added 1 new rows
# UHS: added 1 new rows
# EHC: added 1 new rows
# ENSG: added 1 new rows
# DVA: added 1 new rows
# CHE: added 1 new rows
# PACS: added 5 new rows
# OPCH: added 1 new rows
# BKD: added 1 new rows
# CON: added 1 new rows
# LFST: added 1 new rows
# ADUS: added 1 new rows
# SGRY: added 1 new rows
# NHC: added 1 new rows
# MD: added 1 new rows
# AVAH: added 1 new rows
# SEM: added 1 new rows
# GRDN: added 1 new rows
# ACHC: added 1 new rows
# HCSG: added 1 new rows
# ARDT: added 1 new rows
# ASTH: added 1 new rows
# USPH: added 1 new rows
# PIII: added 1 new rows
# PNTG: added 1 new rows
# NUTX: added 1 new rows
# INNV: added 1 new rows
# AMN: added 1 new rows
# SNDA: added 1 new rows
# EHAB: added 1 new rows
# CCRN: added 1 new rows
# JYNT: added 1 new rows
# ZTS: added 1 new rows
# UTHR: added 1 new rows
# NBIX: added 1 new rows
# VTRS: added 1 new rows
# ELAN: added 1 new rows
# HIMS: added 1 new rows
# ALKS: added 1 new rows
# INDV: added 1 new rows
# LNTH: added 1 new rows
# AMRX: added 1 new rows
# KNSA: added 1 new rows
# PBH: added 1 new rows
# SUPN: added 1 new rows
# AVDL: added 1 new rows
# ANIP: added 1 new rows
# PRGO: added 1 new rows
# PAHC: added 1 new rows
# ALVO: added 1 new rows
# HROW: added 1 new rows
# BCRX: added 1 new rows
# COLL: added 1 new rows
# DVAX: added 1 new rows
# AMPH: added 1 new rows
# PCRX: added 1 new rows
# AQST: added 1 new rows
# ORGO: added 7 new rows
# EBS: added 1 new rows
# EOLS: added 1 new rows
# SIGA: added 1 new rows
# ETON: added 1 new rows
# BIOA: added 1 new rows
# LFCR: added 1 new rows
# DERM: added 1 new rows
# ANIK: added 1 new rows
# EVOK: added 7 new rows
# FLGC: added 1 new rows
# VEEV: added 1 new rows
# GEHC: added 1 new rows
# TEM: added 1 new rows
# DOCS: added 1 new rows
# WAY: added 1 new rows
# BTSG: added 1 new rows
# HNGE: added 1 new rows
# PRVA: added 1 new rows
# HTFL: added 1 new rows
# TXG: added 1 new rows
# PINC: added 1 new rows
# OMCL: added 1 new rows
# CERT: added 1 new rows
# TDOC: added 1 new rows
# SDGR: added 1 new rows
# OMDA: added 1 new rows
# CTEV: added 1 new rows
# HSTM: added 1 new rows
# WEAV: added 1 new rows
# CARL: added 1 new rows
# NRC: added 1 new rows
# TBRG: added 1 new rows
# OPRX: added 1 new rows
# SPOK: added 1 new rows
# DRIO: added 1 new rows
# POAI: added 1 new rows
# ACON: added 1 new rows
# GE: added 1 new rows
# RTX: added 1 new rows
# BA: added 1 new rows
# LMT: added 1 new rows
# GD: added 1 new rows
# HWM: added 1 new rows
# NOC: added 1 new rows
# TDG: added 1 new rows
# LHX: added 1 new rows
# AXON: added 1 new rows
# RKLB: added 1 new rows
# CW: added 1 new rows
# WWD: added 1 new rows
# BWXT: added 1 new rows
# TXT: added 1 new rows
# KTOS: added 1 new rows
# HII: added 1 new rows
# DRS: added 1 new rows
# KRMN: added 1 new rows
# SARO: added 1 new rows
# MOG-A: added 1 new rows
# LOAR: added 1 new rows
# HXL: added 1 new rows
# ACHR: added 1 new rows
# SPR: added 1 new rows
# VSEC: added 1 new rows
# MRCY: added 1 new rows
# FLY: added 1 new rows
# ATRO: added 1 new rows
# CDRE: added 1 new rows
# VVX: added 1 new rows
# DCO: added 1 new rows
# VOYG: added 1 new rows
# LUNR: added 1 new rows
# RDW: added 1 new rows
# RCAT: added 1 new rows
# NPK: added 1 new rows
# RGR: added 1 new rows
# BYRN: added 1 new rows
# PKE: added 1 new rows
# AIRO: added 1 new rows
# SPAI: added 1 new rows
# GEV: added 1 new rows
# ETN: added 1 new rows
# PH: added 1 new rows
# EMR: added 1 new rows
# ITW: added 1 new rows
# CMI: added 1 new rows
# SYM: added 1 new rows
# AME: added 1 new rows
# ROK: added 1 new rows
# OTIS: added 1 new rows
# XYL: added 1 new rows
# IR: added 1 new rows
# DOV: added 1 new rows
# PNR: added 1 new rows
# ITT: added 1 new rows
# GGG: added 1 new rows
# IEX: added 1 new rows
# CR: added 1 new rows
# RRX: added 1 new rows
# FLS: added 1 new rows
# AOS: added 1 new rows
# WTS: added 1 new rows
# GTLS: added 1 new rows
# GNRC: added 1 new rows
# MIR: added 1 new rows
# MIDD: added 1 new rows
# GTES: added 1 new rows
# SMR: added 1 new rows
# NPO: added 1 new rows
# FELE: added 1 new rows
# MWA: added 1 new rows
# KAI: added 1 new rows
# CXT: added 1 new rows
# SXI: added 1 new rows
# HI: added 1 new rows
# EPAC: added 1 new rows
# HLIO: added 1 new rows
# AMSC: added 1 new rows
# TNC: added 1 new rows
# PSIX: added 1 new rows
# GRC: added 1 new rows
# THR: added 1 new rows
# SERV: added 1 new rows
# BW: added 7 new rows
# GHM: added 7 new rows
# CAT: added 1 new rows
# DE: added 1 new rows
# PCAR: added 1 new rows
# CNH: added 1 new rows
# OSK: added 1 new rows
# AGCO: added 1 new rows
# TEX: added 1 new rows
# ALG: added 1 new rows
# BLBD: added 1 new rows
# LNN: added 1 new rows
# KDK: added 7 new rows
# ASTE: added 1 new rows
# AEBI: added 1 new rows
# TWI: added 1 new rows
# HY: added 1 new rows
# CMCO: added 1 new rows
# MTW: added 1 new rows
# WNC: added 1 new rows
# UNP: added 1 new rows
# CSX: added 1 new rows
# NSC: added 1 new rows
# WAB: added 1 new rows
# TRN: added 1 new rows
# GBX: added 1 new rows
# FSTR: added 1 new rows
# RAIL: added 1 new rows
# PWR: added 1 new rows
# FIX: added 1 new rows
# EME: added 1 new rows
# MTZ: added 1 new rows
# APG: added 1 new rows
# J: added 1 new rows
# ACM: added 1 new rows
# BLD: added 1 new rows
# STRL: added 1 new rows
# DY: added 1 new rows
# TTEK: added 1 new rows
# IESC: added 1 new rows
# FLR: added 1 new rows
# PRIM: added 1 new rows
# ROAD: added 1 new rows
# KBR: added 1 new rows
# ACA: added 1 new rows
# LGN: added 1 new rows
# GVA: added 1 new rows
# ECG: added 1 new rows
# EXPO: added 1 new rows
# TPC: added 1 new rows
# MYRG: added 1 new rows
# AMRC: added 1 new rows
# WLDN: added 1 new rows
# GLDD: added 1 new rows
# BWMN: added 1 new rows
# ORN: added 1 new rows
# MTRX: added 1 new rows
# VATE: added 7 new rows
# TT: added 1 new rows
# JCI: added 1 new rows
# CARR: added 1 new rows
# LII: added 1 new rows
# CSL: added 1 new rows
# MAS: added 1 new rows
# BLDR: added 1 new rows
# WMS: added 1 new rows
# SPXC: added 1 new rows
# OC: added 1 new rows
# AWI: added 1 new rows
# AAON: added 1 new rows
# FBIN: added 1 new rows
# LPX: added 1 new rows
# TREX: added 1 new rows
# GFF: added 1 new rows
# ARLO: added 1 new rows
# ROCK: added 1 new rows
# JBI: added 1 new rows
# SWIM: added 1 new rows
# LMB: added 1 new rows
# APOG: added 1 new rows
# SNTL: added 1 new rows
# CPRT: added 1 new rows
# GPN: added 1 new rows
# ULS: added 1 new rows
# ARMK: added 1 new rows
# AMTM: added 1 new rows
# DLB: added 1 new rows
# MMS: added 1 new rows
# AZZ: added 1 new rows
# UNF: added 1 new rows
# CBZ: added 1 new rows
# FA: added 1 new rows
# TIC: added 1 new rows
# CMPR: added 1 new rows
# LZ: added 1 new rows
# RHLD: added 1 new rows
# BV: added 1 new rows
# KUBR: added 1 new rows
# TH: added 1 new rows
# KODK: added 1 new rows
# BKSY: added 1 new rows
# CASS: added 1 new rows
# TRNS: added 1 new rows
# QUAD: added 1 new rows
# WFCF: added 1 new rows
# TISI: added 1 new rows
# HON: added 1 new rows
# MMM: added 1 new rows
# VMI: added 1 new rows
# SEB: added 1 new rows
# OTTR: added 1 new rows
# TTI: added 1 new rows
# DLX: added 1 new rows
# SPLP: added 2 new rows
# FBYD: added 1 new rows
# MATW: added 1 new rows
# TRC: added 1 new rows
# BOC: added 1 new rows
# RCMT: added 1 new rows
# BOOM: added 1 new rows
# AIRT: added 1 new rows
# STRR: added 1 new rows
# WM: added 1 new rows
# RSG: added 1 new rows
# WCN: added 1 new rows
# GFL: added 1 new rows
# CLH: added 1 new rows
# CWST: added 1 new rows
# NVRI: added 1 new rows
# MEG: added 1 new rows
# PESI: added 1 new rows
# LNZA: added 1 new rows
# AQMS: added 1 new rows
# GWAV: added 1 new rows
# FAST: added 1 new rows
# GWW: added 1 new rows
# WSO: added 1 new rows
# WCC: added 1 new rows
# QXO: added 1 new rows
# AIT: added 1 new rows
# POOL: added 1 new rows
# SITE: added 1 new rows
# MSM: added 1 new rows
# REZI: added 1 new rows
# XMTR: added 1 new rows
# DNOW: added 1 new rows
# DXPE: added 1 new rows
# DSGR: added 1 new rows
# GIC: added 1 new rows
# BXC: added 1 new rows
# TITN: added 1 new rows
# EVI: added 1 new rows
# UPS: added 1 new rows
# EXPD: added 1 new rows
# CHRW: added 1 new rows
# JBHT: added 1 new rows
# GXO: added 1 new rows
# LSTR: added 1 new rows
# HUBG: added 1 new rows
# PBI: added 1 new rows
# FWRD: added 1 new rows
# CYRX: added 1 new rows
# RLGT: added 1 new rows
# PAL: added 1 new rows
# VRT: added 1 new rows
# BE: added 1 new rows
# HUBB: added 1 new rows
# NVT: added 1 new rows
# AYI: added 1 new rows
# AEIS: added 1 new rows
# ENS: added 1 new rows
# EOSE: added 1 new rows
# POWL: added 1 new rows
# HAYW: added 1 new rows
# ATKR: added 1 new rows
# ENVX: added 1 new rows
# AMPX: added 1 new rows
# ENR: added 1 new rows
# PLPC: added 1 new rows
# KE: added 1 new rows
# LTBR: added 1 new rows
# EAF: added 1 new rows
# TGEN: added 1 new rows
# ESP: added 1 new rows
# ULBI: added 1 new rows
# STI: added 7 new rows
# OESX: added 1 new rows
# URI: added 1 new rows
# AER: added 1 new rows
# FTAI: added 1 new rows
# UHAL: added 1 new rows
# AL: added 1 new rows
# R: added 1 new rows
# GATX: added 1 new rows
# CAR: added 1 new rows
# HRI: added 1 new rows
# WSC: added 1 new rows
# MGRC: added 1 new rows
# HTZ: added 1 new rows
# CTOS: added 1 new rows
# PRG: added 1 new rows
# WLFC: added 1 new rows
# VSTS: added 6 new rows
# DAL: added 1 new rows
# UAL: added 1 new rows
# LUV: added 1 new rows
# AAL: added 1 new rows
# CPA: added 1 new rows
# ALK: added 1 new rows
# SKYW: added 1 new rows
# ALGT: added 1 new rows
# SNCY: added 1 new rows
# VRSK: added 1 new rows
# EFX: added 1 new rows
# BAH: added 1 new rows
# FCN: added 1 new rows
# HURN: added 1 new rows
# ICFI: added 1 new rows
# CRAI: added 1 new rows
# FORR: added 1 new rows
# ODFL: added 1 new rows
# XPO: added 1 new rows
# SAIA: added 1 new rows
# KNX: added 1 new rows
# SNDR: added 1 new rows
# RXO: added 1 new rows
# WERN: added 1 new rows
# ARCB: added 1 new rows
# MRTN: added 1 new rows
# HTLD: added 1 new rows
# CVLG: added 1 new rows
# ULH: added 1 new rows
# PAMT: added 1 new rows
# SNA: added 1 new rows
# RBC: added 1 new rows
# LECO: added 1 new rows
# SWK: added 1 new rows
# TKR: added 1 new rows
# HLMN: added 1 new rows
# EML: added 1 new rows
# QEPC: added 1 new rows
# CVR: added 1 new rows
# CRS: added 1 new rows
# ATI: added 1 new rows
# MLI: added 1 new rows
# ESAB: added 1 new rows
# PRLB: added 1 new rows
# RYI: added 1 new rows
# IIIN: added 1 new rows
# MEC: added 1 new rows
# TG: added 1 new rows
# GIFI: added 1 new rows
# VLTO: added 1 new rows
# ZWS: added 1 new rows
# FSS: added 1 new rows
# CECO: added 1 new rows
# PCT: added 1 new rows
# ERII: added 1 new rows
# RAIN: added 1 new rows
# ALLE: added 1 new rows
# ADT: added 1 new rows
# MSA: added 1 new rows
# BCO: added 1 new rows
# BRC: added 1 new rows
# GEO: added 1 new rows
# CXW: added 1 new rows
# NSSC: added 1 new rows
# EVLV: added 1 new rows
# MG: added 1 new rows
# CIX: added 1 new rows
# NL: added 1 new rows
# KEX: added 1 new rows
# MATX: added 1 new rows
# ZIM: added 1 new rows
# CMRE: added 1 new rows
# DAC: added 1 new rows
# GSL: added 1 new rows
# CCEC: added 1 new rows
# SFL: added 1 new rows
# GNK: added 1 new rows
# SB: added 5 new rows
# ASC: added 1 new rows
# PANL: added 1 new rows
# ESEA: added 1 new rows
# CMDB: added 1 new rows
# GASS: added 1 new rows
# SHIP: added 1 new rows
# SMHI: added 1 new rows
# EDRY: added 1 new rows
# EHLD: added 1 new rows
# JOBY: added 1 new rows
# CAAP: added 1 new rows
# ASLE: added 1 new rows
# TNET: added 1 new rows
# RHI: added 1 new rows
# NSP: added 1 new rows
# MAN: added 1 new rows
# HSII: added 1 new rows
# BBSI: added 1 new rows
# KFRC: added 1 new rows
# KELYA: added 1 new rows
# HQI: added 1 new rows
# MHH: added 1 new rows
# AMT: added 1 new rows
# EQIX: added 1 new rows
# DLR: added 1 new rows
# CCI: added 1 new rows
# IRM: added 1 new rows
# SBAC: added 1 new rows
# WY: added 1 new rows
# LAMR: added 1 new rows
# GLPI: added 1 new rows
# FRMI: added 2 new rows
# EPR: added 1 new rows
# OUT: added 1 new rows
# RYN: added 1 new rows
# PCH: added 1 new rows
# UNIT: added 1 new rows
# FPI: added 1 new rows
# LAND: added 1 new rows
# NLCP: added 1 new rows
# SELF: added 1 new rows
# PLD: added 1 new rows
# PSA: added 1 new rows
# EXR: added 1 new rows
# REXR: added 1 new rows
# EGP: added 1 new rows
# LINE: added 1 new rows
# CUBE: added 1 new rows
# FR: added 1 new rows
# STAG: added 1 new rows
# TRNO: added 1 new rows
# NSA: added 1 new rows
# COLD: added 1 new rows
# LXP: added 1 new rows
# SMA: added 1 new rows
# IIPR: added 1 new rows
# PLYM: added 1 new rows
# ILPT: added 1 new rows
# MDV: added 1 new rows
# WELL: added 1 new rows
# VTR: added 1 new rows
# OHI: added 1 new rows
# DOC: added 1 new rows
# AHR: added 1 new rows
# CTRE: added 1 new rows
# HR: added 1 new rows
# SBRA: added 1 new rows
# NHI: added 1 new rows
# MPW: added 1 new rows
# LTC: added 1 new rows
# SILA: added 1 new rows
# GMRE: added 1 new rows
# STRW: added 1 new rows
# UHT: added 1 new rows
# CHCT: added 1 new rows
# SPG: added 1 new rows
# O: added 1 new rows
# KIM: added 1 new rows
# REG: added 1 new rows
# ADC: added 1 new rows
# FRT: added 1 new rows
# BRX: added 1 new rows
# NNN: added 1 new rows
# EPRT: added 1 new rows
# KRG: added 1 new rows
# PECO: added 1 new rows
# MAC: added 1 new rows
# SKT: added 1 new rows
# AKR: added 1 new rows
# UE: added 1 new rows
# FCPT: added 1 new rows
# CURB: added 1 new rows
# IVT: added 1 new rows
# NTST: added 1 new rows
# GTY: added 1 new rows
# ALEX: added 1 new rows
# ALX: added 1 new rows
# BFS: added 1 new rows
# CBL: added 1 new rows
# WSR: added 1 new rows
# SITC: added 1 new rows
# PINE: added 1 new rows
# AVB: added 1 new rows
# EQR: added 1 new rows
# ESS: added 1 new rows
# INVH: added 1 new rows
# SUI: added 1 new rows
# MAA: added 1 new rows
# UDR: added 1 new rows
# AMH: added 1 new rows
# ELS: added 1 new rows
# CPT: added 1 new rows
# IRT: added 1 new rows
# VRE: added 1 new rows
# NXRT: added 1 new rows
# ELME: added 1 new rows
# UMH: added 1 new rows
# CSR: added 1 new rows
# AIV: added 1 new rows
# BRT: added 1 new rows
# BHM: added 1 new rows
# CBRE: added 1 new rows
# CSGP: added 1 new rows
# JLL: added 1 new rows
# OPEN: added 1 new rows
# COMP: added 1 new rows
# NMRK: added 1 new rows
# CWK: added 1 new rows
# IHS: added 1 new rows
# EXPI: added 1 new rows
# HOUS: added 1 new rows
# KW: added 1 new rows
# MMI: added 1 new rows
# FRPH: added 1 new rows
# RMAX: added 1 new rows
# TCI: added 1 new rows
# MLP: added 1 new rows
# SEG: added 1 new rows
# RMR: added 1 new rows
# ARL: added 1 new rows
# LHAI: added 1 new rows
# STHO: added 1 new rows
# ASPS: added 1 new rows
# NYC: added 1 new rows
# NLY: added 1 new rows
# AGNC: added 1 new rows
# STWD: added 1 new rows
# RITM: added 1 new rows
# BXMT: added 1 new rows
# DX: added 1 new rows
# ARR: added 1 new rows
# ABR: added 1 new rows
# EFC: added 1 new rows
# LADR: added 1 new rows
# ARI: added 1 new rows
# ORC: added 1 new rows
# PMT: added 1 new rows
# CIM: added 1 new rows
# TWO: added 1 new rows
# MFA: added 1 new rows
# FBRT: added 1 new rows
# BRSP: added 1 new rows
# TRTX: added 1 new rows
# RWT: added 1 new rows
# ADAM: added 1 new rows
# IVR: added 1 new rows
# KREF: added 1 new rows
# NREF: added 1 new rows
# ACRE: added 7 new rows
# REFI: added 1 new rows
# MITT: added 1 new rows
# AOMR: added 1 new rows
# ACR: added 1 new rows
# SUNS: added 1 new rows
# SEVN: added 1 new rows
# BXP: added 1 new rows
# ARE: added 1 new rows
# VNO: added 1 new rows
# KRC: added 1 new rows
# CUZ: added 1 new rows
# SLG: added 1 new rows
# HIW: added 1 new rows
# DEI: added 1 new rows
# ESBA: added 1 new rows
# PGRE: added 1 new rows
# JBGS: added 1 new rows
# DEA: added 1 new rows
# PDM: added 1 new rows
# PSTL: added 1 new rows
# PKST: added 1 new rows
# NLOP: added 1 new rows
# CIO: added 1 new rows
# VICI: added 1 new rows
# WPC: added 1 new rows
# BNL: added 1 new rows
# ESRT: added 1 new rows
# GNL: added 1 new rows
# AAT: added 1 new rows
# SAFE: added 1 new rows
# AHH: added 1 new rows
# CTO: added 1 new rows
# GOOD: added 1 new rows
# OLP: added 1 new rows
# FVR: added 1 new rows
# MDRR: added 1 new rows
# HST: added 1 new rows
# RHP: added 1 new rows
# APLE: added 1 new rows
# PK: added 1 new rows
# DRH: added 1 new rows
# SHO: added 1 new rows
# XHR: added 1 new rows
# PEB: added 1 new rows
# RLJ: added 1 new rows
# INN: added 1 new rows
# CLDT: added 1 new rows
# HHH: added 1 new rows
# CCS: added 1 new rows
# FOR: added 1 new rows
# FPH: added 1 new rows
# SKYH: added 1 new rows
# OZ: added 1 new rows
# JFB: added 1 new rows
# SDHC: added 1 new rows
# JOE: added 1 new rows
# STRS: added 1 new rows
# NVDA: added 1 new rows
# AMD: added 1 new rows
# INTC: added 1 new rows
# QCOM: added 1 new rows
# TXN: added 1 new rows
# ADI: added 1 new rows
# NXPI: added 1 new rows
# MPWR: added 1 new rows
# MCHP: added 1 new rows
# ALAB: added 1 new rows
# ON: added 1 new rows
# GFS: added 1 new rows
# MTSI: added 1 new rows
# RMBS: added 1 new rows
# SWKS: added 1 new rows
# LSCC: added 1 new rows
# QRVO: added 1 new rows
# SITM: added 1 new rows
# SMTC: added 1 new rows
# CRUS: added 1 new rows
# PI: added 1 new rows
# ALGM: added 1 new rows
# SLAB: added 1 new rows
# SYNA: added 1 new rows
# DIOD: added 1 new rows
# NVTS: added 1 new rows
# POWI: added 1 new rows
# VSH: added 1 new rows
# LASR: added 1 new rows
# MXL: added 1 new rows
# SKYT: added 1 new rows
# AIP: added 1 new rows
# AOSL: added 1 new rows
# CEVA: added 1 new rows
# WOLF: added 1 new rows
# AMBQ: added 1 new rows
# NVEC: added 1 new rows
# ALMU: added 1 new rows
# GSIT: added 7 new rows
# MRAM: added 1 new rows
# QUIK: added 1 new rows
# PXLW: added 1 new rows
# MSFT: added 1 new rows
# PLTR: added 1 new rows
# PANW: added 1 new rows
# NET: added 1 new rows
# FTNT: added 1 new rows
# XYZ: added 1 new rows
# ZS: added 1 new rows
# CRWV: added 1 new rows
# VRSN: added 1 new rows
# AFRM: added 1 new rows
# CYBR: added 1 new rows
# NTAP: added 1 new rows
# CPAY: added 1 new rows
# CHKP: added 1 new rows
# TOST: added 1 new rows
# TWLO: added 1 new rows
# GDDY: added 1 new rows
# GEN: added 1 new rows
# FFIV: added 1 new rows
# NTNX: added 1 new rows
# AKAM: added 1 new rows
# DOX: added 1 new rows
# DBX: added 1 new rows
# CFLT: added 1 new rows
# INFA: added 1 new rows
# BLSH: added 1 new rows
# FOUR: added 1 new rows
# WIX: added 1 new rows
# CORZ: added 1 new rows
# OS: added 7 new rows
# WEX: added 1 new rows
# QLYS: added 1 new rows
# ACIW: added 1 new rows
# STNE: added 1 new rows
# ZETA: added 1 new rows
# PAY: added 7 new rows
# AAPL: added 1 new rows
# SONO: added 1 new rows
# TBCH: added 1 new rows
# KOSS: added 1 new rows
# AXIL: added 1 new rows
# SHOP: added 7 new rows
# UBER: added 1 new rows
# INTU: added 1 new rows
# NOW: added 1 new rows
# ADP: added 1 new rows
# CDNS: added 1 new rows
# ADSK: added 1 new rows
# WDAY: added 1 new rows
# DDOG: added 1 new rows
# MSTR: added 1 new rows
# ROP: added 1 new rows
# FICO: added 1 new rows
# PAYX: added 1 new rows
# TEAM: added 1 new rows
# ZM: added 1 new rows
# GRAB: added 1 new rows
# PTC: added 1 new rows
# SSNC: added 1 new rows
# TYL: added 1 new rows
# HUBS: added 1 new rows
# U: added 1 new rows
# FIG: added 1 new rows
# DT: added 1 new rows
# BSY: added 1 new rows
# PCOR: added 1 new rows
# DAY: added 1 new rows
# MANH: added 1 new rows
# PEGA: added 1 new rows
# IDCC: added 1 new rows
# PAYC: added 1 new rows
# DUOL: added 1 new rows
# KVYO: added 1 new rows
# LYFT: added 1 new rows
# APPF: added 1 new rows
# PCTY: added 1 new rows
# CHYM: added 1 new rows
# ESTC: added 1 new rows
# MNDY: added 1 new rows
# FROG: added 1 new rows
# CWAN: added 1 new rows
# SRAD: added 1 new rows
# LIF: added 1 new rows
# CVLT: added 1 new rows
# IBM: added 1 new rows
# CTSH: added 1 new rows
# FIS: added 1 new rows
# FI: added 1 new rows
# FISV: added 7 new rows
# BR: added 1 new rows
# LDOS: added 1 new rows
# CDW: added 1 new rows
# IT: added 1 new rows
# CACI: added 1 new rows
# JKHY: added 1 new rows
# EPAM: added 1 new rows
# PSN: added 1 new rows
# G: added 1 new rows
# APLD: added 1 new rows
# EXLS: added 1 new rows
# KD: added 1 new rows
# INGM: added 1 new rows
# VRRM: added 1 new rows
# GLOB: added 1 new rows
# BBAI: added 1 new rows
# DXC: added 1 new rows
# ASGN: added 1 new rows
# INOD: added 1 new rows
# VYX: added 1 new rows
# NABL: added 1 new rows
# PENG: added 1 new rows
# TASK: added 1 new rows
# GDYN: added 1 new rows
# HCKT: added 1 new rows
# IBEX: added 1 new rows
# TTGT: added 1 new rows
# TSSI: added 1 new rows
# III: added 1 new rows
# WYY: added 7 new rows
# AMAT: added 1 new rows
# LRCX: added 1 new rows
# KLAC: added 1 new rows
# TER: added 1 new rows
# Q: added 6 new rows
# ENTG: added 1 new rows
# NVMI: added 1 new rows
# AMKR: added 1 new rows
# SOLSV: added 3 new rows
# ONTO: added 1 new rows
# CAMT: added 1 new rows
# FORM: added 1 new rows
# IPGP: added 1 new rows
# AMBA: added 1 new rows
# ACLS: added 1 new rows
# KLIC: added 1 new rows
# ACMR: added 1 new rows
# VECO: added 1 new rows
# UCTT: added 1 new rows
# COHU: added 1 new rows
# AEHR: added 1 new rows
# ICHR: added 1 new rows
# AXTI: added 7 new rows
# INTT: added 1 new rows
# TRT: added 1 new rows
# CSCO: added 1 new rows
# MSI: added 1 new rows
# UI: added 1 new rows
# LITE: added 1 new rows
# ASTS: added 1 new rows
# ZBRA: added 1 new rows
# VSAT: added 1 new rows
# BDC: added 1 new rows
# COMM: added 1 new rows
# VIAV: added 1 new rows
# ONDS: added 1 new rows
# EXTR: added 1 new rows
# AAOI: added 1 new rows
# DGII: added 1 new rows
# HLIT: added 1 new rows
# NTGR: added 1 new rows
# GILT: added 1 new rows
# ADTN: added 1 new rows
# AVNW: added 1 new rows
# BKTI: added 1 new rows
# LTRX: added 7 new rows
# INSG: added 1 new rows
# SILC: added 1 new rows
# CLRO: added 1 new rows
# SONM: added 7 new rows
# ANET: added 1 new rows
# DELL: added 1 new rows
# STX: added 1 new rows
# WDC: added 1 new rows
# SNDK: added 1 new rows
# HPQ: added 1 new rows
# SMCI: added 1 new rows
# IONQ: added 1 new rows
# RGTI: added 1 new rows
# QBTS: added 1 new rows
# QUBT: added 1 new rows
# SSYS: added 1 new rows
# CRSR: added 1 new rows
# UMAC: added 1 new rows
# OSS: added 1 new rows
# VELO: added 7 new rows
# QMCO: added 1 new rows
# APH: added 1 new rows
# GLW: added 1 new rows
# TEL: added 1 new rows
# FLEX: added 1 new rows
# FN: added 1 new rows
# SANM: added 1 new rows
# TTMI: added 1 new rows
# LFUS: added 1 new rows
# OLED: added 1 new rows
# RAL: added 1 new rows
# OSIS: added 1 new rows
# VICR: added 1 new rows
# PLXS: added 1 new rows
# BELFB: added 1 new rows
# KN: added 1 new rows
# BHE: added 1 new rows
# ROG: added 1 new rows
# OUST: added 1 new rows
# CTS: added 1 new rows
# ALNT: added 1 new rows
# LYTS: added 1 new rows
# LPTH: added 1 new rows
# RELL: added 1 new rows
# MPTI: added 1 new rows
# ELTK: added 1 new rows
# GRMN: added 1 new rows
# KEYS: added 1 new rows
# COHR: added 1 new rows
# TDY: added 1 new rows
# TRMB: added 1 new rows
# FTV: added 1 new rows
# MKSI: added 1 new rows
# CGNX: added 1 new rows
# ESE: added 1 new rows
# VNT: added 1 new rows
# BMI: added 1 new rows
# ST: added 1 new rows
# ITRI: added 1 new rows
# NOVT: added 1 new rows
# ITRN: added 1 new rows
# VPG: added 1 new rows
# MLAB: added 1 new rows
# ACFN: added 1 new rows
# AATC: added 1 new rows
# LGL: added 1 new rows
# WATT: added 1 new rows
# FSLR: added 1 new rows
# NXT: added 1 new rows
# RUN: added 1 new rows
# ENPH: added 1 new rows
# SEDG: added 1 new rows
# CSIQ: added 1 new rows
# SHLS: added 1 new rows
# ARRY: added 1 new rows
# FTCI: added 1 new rows
# ARW: added 1 new rows
# AVT: added 1 new rows
# NSIT: added 1 new rows
# CNXN: added 1 new rows
# SCSC: added 1 new rows
# CLMB: added 1 new rows
# NEE: added 1 new rows
# SO: added 1 new rows
# DUK: added 1 new rows
# AEP: added 1 new rows
# D: added 1 new rows
# XEL: added 1 new rows
# EXC: added 1 new rows
# ETR: added 1 new rows
# PEG: added 1 new rows
# WEC: added 1 new rows
# ED: added 1 new rows
# PCG: added 1 new rows
# AEE: added 1 new rows
# DTE: added 1 new rows
# FE: added 1 new rows
# PPL: added 1 new rows
# CNP: added 1 new rows
# ES: added 1 new rows
# CMS: added 1 new rows
# EIX: added 1 new rows
# EVRG: added 1 new rows
# LNT: added 1 new rows
# PNW: added 1 new rows
# OGE: added 1 new rows
# IDA: added 1 new rows
# TXNM: added 1 new rows
# POR: added 1 new rows
# NWE: added 1 new rows
# MGEE: added 1 new rows
# HE: added 1 new rows
# IMSR: added 4 new rows
# GNE: added 1 new rows
# CEG: added 1 new rows
# VST: added 1 new rows
# NRG: added 1 new rows
# TLN: added 1 new rows
# OKLO: added 1 new rows
# TLNE: added 1 new rows
# ATO: added 1 new rows
# NI: added 1 new rows
# UGI: added 1 new rows
# SWX: added 1 new rows
# BKH: added 1 new rows
# SR: added 1 new rows
# OGS: added 1 new rows
# NJR: added 1 new rows
# MDU: added 1 new rows
# CPK: added 1 new rows
# CTRI: added 1 new rows
# NWN: added 1 new rows
# SPH: added 1 new rows
# RGCO: added 1 new rows
# SRE: added 1 new rows
# AES: added 1 new rows
# ALE: added 1 new rows
# AVA: added 1 new rows
# UTL: added 1 new rows
# CWEN-A: added 1 new rows
# ORA: added 1 new rows
# FLNC: added 1 new rows
# RNW: added 1 new rows
# XIFR: added 1 new rows
# ELLO: added 1 new rows
# STEM: added 1 new rows
# BESS: added 1 new rows
# AWK: added 1 new rows
# WTRG: added 1 new rows
# AWR: added 1 new rows
# CWT: added 1 new rows
# MSEX: added 1 new rows
# CWCO: added 1 new rows
# YORW: added 1 new rows
# CDZI: added 6 new rows
# ARTNA: added 1 new rows
# PCYO: added 1 new rows
# GWRS: added 1 new rows

# %% [markdown]
# # Database Setup

# %%
from sqlalchemy import create_engine

# Connect to SQLite database (file-based)
engine = create_engine('sqlite:///financial_analytics.db')  # This creates database in the current folder

# %% [markdown]
# We will create some master tables from the sector, industry, market and top companies data. These will follow a naming convention of starting with 'M' (e.g. <b>MSECTOR</b>).
#
# Then we will create the operational tables which will be periodically updated. <i>(Maybe every quarter?)</i>

# %% [markdown]
# ### Master Tables

# %%
# Write DataFrame to SQL (replace table if exists)
sectors_df.to_sql('MSECTOR', engine, if_exists='replace', index=False)
industries_df.to_sql('MINDUSTRY', engine, if_exists='replace', index=False)
sector_industry_df.to_sql('MSECTORINDUSTRY', engine, if_exists='replace', index=False)
markets_df.to_sql('MMARKET', engine, if_exists='replace', index=False)
top_companies.to_sql('MCOMPANIES', engine, if_exists='replace', index=True)
# Out:
# 2674

# %%
new_ticker_df

# %% [markdown]
# ### Metrics tables

# %%
#########################################################
##########         FIRST TIME ONLY !!!         ##########
#########################################################

# Write DataFrame to SQL (first time)
#ticker_df.to_sql('TGTMETRICS', engine, if_exists='replace', index=False)

#########################################################
#########################################################

# Write DataFrame to SQL (new data)
new_ticker_df.to_sql('TGTMETRICS', engine, if_exists='append', index=False)
# Out:
# 17233

# %% [markdown]
# # Fundamental Trading Strategies

# %% [markdown]
# ### Gross Profit Growth Strategy
# Gross profit represents a company's revenue after deducting the cost of goods sold, and its growth indicates the company's **efficiency** and **pricing power**.
#
# - *<u>Identify growing margins</u>*: Investors can look for companies that consistently increase their gross profit margin, which suggests effective management of production costs or the ability to charge higher prices.
#
# - *<u>Industry comparison</u>>*: Comparing a company's gross margin with its industry peers can reveal if it's more efficient at converting sales into profit. A company with higher gross profit growth relative to competitors may have a competitive advantage.

# %% [markdown]
# ### Total Revenue Growth Strategy
# Consistent total revenue growth indicates **increasing demand for a company's products or services** and **market expansion**.
#
# - *<u>Track growth trends</u>*: Look for companies with sustainable and steady revenue growth over time. While an annual growth rate of 15% to 25% is often considered healthy, extremely high rates might overwhelm a business.
#
# - *<u>Screen for growth stocks</u>*: Use stock screeners to find companies with accelerating revenue growth, which can signal high-potential growth stocks.
#
# - *<u>Assess competitive position</u>*: Evaluate revenue growth in the context of industry trends and macroeconomic factors. Companies that can maintain growth despite economic headwinds are often considered resilient.

# %% [markdown]
# ### Free Cash Flow Growth Strategy
# Free cash flow (FCF) is the cash a company generates after covering its operating expenses and capital expenditures. Strong FCF growth is a sign of **financial health** and **flexibility**.
#
# - *<u>High FCF yield</u>*: A high FCF yield, which compares FCF per share to the market value per share, indicates that a company can easily meet its obligations and return cash to shareholders.
#
# - *<u>Financial flexibility</u>*: Companies with strong FCF can reinvest in the business, make acquisitions, pay dividends, or buy back shares, all of which can enhance shareholder value.
#
# - *<u>All-weather strategy</u>*: Strategies based on strong FCF can be effective in all market conditions, as they focus on a company's fundamental ability to generate cash.

# %% [markdown]
# ## Integrated Strategy
# To find **financially robust** companies, investors can combine all three metrics in a screening process:
#
# 1. **<u>Start with revenue</u>**: Screen for companies with consistent revenue growth to identify businesses with strong market demand.
#
# 2. **<u>Refine with gross profit</u>**: Filter for companies that are also growing their gross profit. This ensures the revenue growth is translating into profitability and isn't solely driven by price reductions.
#
# 3. **<u>Confirm with free cash flow</u>**: Select the final companies based on their free cash flow growth. This step confirms that the company is effectively managing its cash and has the financial strength to support future growth and reward investors.

# %%
def integrated_strategy():
    df = pd.read_sql('SELECT * FROM GROWTH_STRATEGIES', engine)

    ## find financial robustness based on 3 metrics
    
    rating = df['rating'].isin(['Strong Buy','Buy'])
    
    # Total Revenue signals
    health = (df['TotalRevenueGrowthAvg'] > 15) & (df['TotalRevenueGrowthAvg'] <= 25)
    rank = df['TotalRevenueIndustryRank'] >= 5
    performance = df['TotalRevenueGrowthPerformance'] == 'Overperforms'
    df['Signal_Revenue'] = (
        np.where(rating, 1, 0) + 
        np.where(health, 1, 0) + 
        np.where(rank, 1, 0) + 
        np.where(performance, 1, 0)
        )
    
    # Gross Profit signals
    rank = df['GrossProfitIndustryRank'] >= 5
    performance = df['GrossProfitGrowthPerformance'] == 'Overperforms'
    df['Signal_GrossProfit'] = (
        np.where(rating, 1, 0) + 
        np.where(rank, 1, 0) + 
        np.where(performance, 1, 0)
        )
    
    # Free Cash Flow signals
    rank = df['FreeCashFlowIndustryRank'] >= 5
    performance = df['FreeCashFlowGrowthPerformance'] == 'Overperforms'
    df['Signal_FreeCashFlow'] = (
        np.where(rating, 1, 0) + 
        np.where(rank, 1, 0) + 
        np.where(performance, 1, 0)
        )

    # Integrated Strategy
    df['Signal'] = df['Signal_Revenue'] + df['Signal_GrossProfit'] + df['Signal_FreeCashFlow']
    df['Fundamentals'] = np.where(df['Signal'] >= 9, 'ROBUST', None)

    return df

# %% [markdown]
# # Technical Trading Strategies

# %% [markdown]
# ## Moving Average Crossover Strategy
# **Pros**: Use when markets are moving strongly in one direction. This strategy helps capture the trend without getting caught in the short-term noise.
#
# **Cons**: Lagging signals mean traders may enter late and exit after the trend shifts.

# %%
def moving_average_crossover(ticker, short_window, long_window):
    df = yf.download(ticker, start='2022-01-01', end=dt.datetime.today())
    
    # define moving averages
    df['Short_MA'] = df['Close'].rolling(window=short_window).mean()
    df['Long_MA'] = df['Close'].rolling(window=long_window).mean()

    # buy/sell signals
    df['Signal'] = np.where(df['Short_MA'] > df['Long_MA'], 'buy', 'sell')

    # plot the strategy
    fig, ax = plt.subplots(figsize=(10,5))
    ax.plot(df.index, df['Close'], label='Stock Price', color='black')
    ax.plot(df.index, df['Short_MA'], label=f'{short_window}-day MA', color='blue', linestyle='dashed')
    ax.plot(df.index, df['Long_MA'], label=f'{long_window}-day MA', color='orange', linestyle='dashed')
    ax.grid(True, which='both', axis='both', alpha=0.3)
    ax.legend()
    signal = df['Signal'][-1]
    color  = 'green' if signal == 'buy' else 'red'
    ax.plot(df.index[-1], df['Short_MA'][-1], marker='o', markersize=10, markerfacecolor='none', markeredgecolor='green', markeredgewidth=2)
    ax.plot(df.index[-1], df['Long_MA'][-1], marker='o', markersize=10, markerfacecolor='none', markeredgecolor='red', markeredgewidth=2)
    fig.suptitle(f"({ticker}) Moving Average Crossover Strategy")
    ax.set_title(f'Current Signal: {signal}', color=color)
    plt.show()

# %%
moving_average_crossover('RIOT', 50, 200)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Mean Reversion Strategy (Z-Score based)
# **Pros**: Use in markets without a clear trend, prices often revert to historical averages.
#
# **Cons**: Requires careful risk management --> if stock is dropping due to real fundamental problems, betting on a reboaund can be dangerous.

# %%
def mean_reversion(ticker, window):
    df = yf.download(ticker, start='2022-01-01', end=dt.datetime.today())

    # calculate z-score for mean reversion
    df['Rolling_Mean'] = df['Close'].rolling(window=window).mean()
    df['Rolling_Std'] = df['Close'].rolling(window=window).std()
    df['Z_Score'] = (df['Close'][ticker] - df['Rolling_Mean']) / df['Rolling_Std']

    # buy when z-score < -2, sell when it returns
    df['Signal'] = np.where(df['Z_Score']< -2, 'buy', np.where(df['Z_Score'] > 0, 'sell', 'hold'))

    # plot the strategy
    fig, ax = plt.subplots(figsize=(10,5))
    ax.plot(df.index, df['Z_Score'], label='Z-Score', color='black')
    ax.axhline(y=2, label=f'Upper Threshold (+2)', color='red', linestyle='dashed')
    ax.axhline(y=0, label=f'Mean', color='gray', linestyle='dashed')
    ax.axhline(y=-2, label=f'Lower Threshold (-2)', color='green', linestyle='dashed')
    ax.grid(True, which='both', axis='both', alpha=0.3)
    ax.legend()
    signal = df['Signal'][-1]
    color  = 'green' if signal == 'buy' else 'red' if signal == 'sell' else 'gray'
    ax.plot(df.index[-1], df['Z_Score'][-1], marker='o', markersize=10, markerfacecolor='none', markeredgecolor=color, markeredgewidth=2)
    fig.suptitle(f"({ticker}) Mean Reversion Strategy (Z-Score)")
    ax.set_title(f'Current Signal: {signal}', color=color)
    plt.show()

# %%
mean_reversion('RIOT', 50)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Momentum Trading Strategy
# **Pros**: Use when markets are rising aggressively.
#
# **Cons**: Can collapse in bear markets, leading to sharp losses.

# %%
def momentum(ticker):
    df = yf.download(ticker, start='2022-01-01', end=dt.datetime.today())

    # calculate the momentum over the past 6 months
    df['Momentum'] = df['Close'].pct_change(periods=120)

    # buy top 10% of stocks, sell bottom 10%
    df['Signal'] = np.where(df['Momentum'] > df['Momentum'].quantile(0.9), 'buy', np.where(df['Momentum'] < df['Momentum'].quantile(0.1), 'sell', 'hold'))

    # plot the strategy
    fig, ax = plt.subplots(figsize=(10,5))
    ax.plot(df.index, df['Momentum'], label='Momentum', color='black')
    ax.axhline(y=df['Momentum'].quantile(0.9), label=f'Top 10% Threshold', color='green', linestyle='dashed')
    ax.axhline(y=df['Momentum'].quantile(0.1), label=f'Bottom 10% Threshold', color='red', linestyle='dashed')
    ax.grid(True, which='both', axis='both', alpha=0.3)
    ax.legend()
    signal = df['Signal'][-1]
    color  = 'green' if signal == 'buy' else 'red' if signal == 'sell' else 'gray'
    ax.plot(df.index[-1], df['Momentum'][-1], marker='o', markersize=10, markerfacecolor='none', markeredgecolor=color, markeredgewidth=2)
    fig.suptitle(f"({ticker}) Momentum Strategy")
    ax.set_title(f'Current Signal: {signal}', color=color)
    plt.show()

# %%
momentum('RIOT')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Selecting Stocks
# We will use the following criteria when selecting stocks for our portfolio:
#
# - Financially ROBUST companies
#
# - 95th percentile in GP, TR and FCF Growth
#
# - (TBA) Best all-weather performance (buy or hold signals) for the 3 types of markets evaluated in the technical analysis

# %%
def stock_selector(amount, currency, filter=True):
    df = integrated_strategy()

    # filter for robust companies
    robust = df[df['Fundamentals'] == 'ROBUST']

    # assign weights to metrics --> favor FCF as it denotes a company with more flexibility (resilience)
    weights = {
        'TotalRevenueGrowthAvg': 0.3,
        'GrossProfitGrowthAvg': 0.3,
        'FreeCashFlowGrowthAvg': 0.4
    }

    # clean df and calculate if they are above the 90/95th percentile for the 3 metrics
    top_stocks = robust.loc[:, ['ticker','sector','industry', 'TotalRevenueGrowthAvg','GrossProfitGrowthAvg','FreeCashFlowGrowthAvg']]

    # calculate weighted metrics and percentile rank
    metrics = ['TotalRevenueGrowthAvg','GrossProfitGrowthAvg','FreeCashFlowGrowthAvg']
    for m in metrics:
        top_stocks[m] = top_stocks[m] * weights.get(m)
    top_stocks['Percentile'] = (
        top_stocks['TotalRevenueGrowthAvg'].rank(pct=True) +
        top_stocks['GrossProfitGrowthAvg'].rank(pct=True) +
        top_stocks['FreeCashFlowGrowthAvg'].rank(pct=True)
    )
    
    # get filtered list of stocks and add 
    stock_list = top_stocks[top_stocks['Percentile'] > 2.5][['ticker','sector','Percentile']].sort_values(by='Percentile', ascending=False)
    
    # get FX conversion from my input in CZK to USD stock prize, if necessary
    def get_czk_usd_rate():
        url = "https://api.frankfurter.app/latest"
        params = {
            "from": "CZK",
            "to": "USD",
        }
        resp = requests.get(url, params=params)
        resp.raise_for_status()          # will raise error if request failed
        data = resp.json()
        return data["rates"]["USD"], data["date"]
    
    if currency == 'CZK':
        rate, date = get_czk_usd_rate()
        USD_amount = rate * amount
        print(f"FX {amount} CZK→USD on {date}: {USD_amount} USD")
    else:
        USD_amount = amount

    # get last close price for stock list
    last_close = yf.download(stock_list['ticker'].tolist(), period='1d')['Close'].iloc[-1]
    stock_list['Price'] = stock_list['ticker'].map(last_close)

    # get priority from percentiles
    stock_list['Priority'] = stock_list['Percentile'] / stock_list['Percentile'].sum()

    # ideal dollar allocation
    stock_list['target_alloc_usd'] = stock_list['Priority'] * USD_amount

    # first pass: buy floor shares based on ideal allocation
    stock_list['Shares'] = (stock_list['target_alloc_usd'] // stock_list['Price']).astype(int)

    # calculate actual allocated dollars
    stock_list['allocated_usd'] = stock_list['Shares'] * stock_list['Price']

    # leftover cash
    cash_left = USD_amount - stock_list['allocated_usd'].sum()

    # greedy topping-up: buy extra shares in order of priority while you still have cash
    while True:
        affordable = stock_list[stock_list['Price'] <= cash_left]
        if affordable.empty:
            break
        
        # pick the highest-priority affordable stock
        idx = affordable.sort_values('Priority', ascending=False).index[0]
        
        # buy one more share of it
        stock_list.loc[idx, 'Shares'] += 1
        stock_list.loc[idx, 'allocated_usd'] = stock_list.loc[idx, 'Shares'] * stock_list.loc[idx, 'Price']
        
        # update leftover cash
        cash_left = USD_amount - stock_list['allocated_usd'].sum()

    stock_list['final_weight_pct'] = round(stock_list['allocated_usd'] / USD_amount * 100, 2)

    # final clean list of stocks with amount of shares, allocated USD and % in portfolio
    if filter is True:
        selected_stocks = stock_list[stock_list['Shares'] > 0][['ticker','sector','Price','Shares', 'allocated_usd', 'final_weight_pct']]
    else:
        selected_stocks = stock_list[['ticker','sector','Price','Shares', 'allocated_usd', 'final_weight_pct']].copy()
    selected_stocks[['Price','allocated_usd']] = round(selected_stocks[['Price','allocated_usd']], 2)
    
    return selected_stocks

# %%
stock_selector(100, 'USD', False)
# Out:
# [*********************100%***********************]  8 of 8 completed
#      ticker                  sector   Price  Shares  allocated_usd  \
# 400    WULF      financial-services   15.51       5          77.55
# 396    RIOT      financial-services   16.13       0           0.00
# 15     AIRO             industrials    8.65       1           8.65
# 1488     LB                  energy   56.95       0           0.00
# 2535    OGS               utilities   83.74       0           0.00
# 786     LYV  communication-services  131.45       0           0.00
# 1323   GKOS              healthcare  106.29       0           0.00
# 1783   SUNS             real-estate   10.05       1          10.05
#
#       final_weight_pct
# 400              77.55
# 396               0.00
# 15                8.65
# 1488              0.00
# 2535              0.00
# 786               0.00
# 1323              0.00
# 1783             10.05

# %% [markdown]
# # Markets

# %% [markdown]
# Track the performance of three types of markets, each one corresponding to the geographic areas found to be most important in international diversification.
#
# 1. Service Economy - Europe (Switzerland) - Proxy ETF: *EWL*
#
# 2. Manufacturing Economy - Asia (Japan) - Proxy ETF: *EWJ*
#
# 3. Balanced Economy - America (USA) - Proxy ETF: *SPY*

# %% [markdown]
# ## Market Trends and Regime Changes
#
# 1. We will track each of the markets and identify when they are
# - moving strongly in a specific direction,
# - rising aggressively, or
# - without any clear trend.
#
#     This is to be able to use our technical trading strategy signals more efficiently.
#
# 2. Afterwards we will also try to predict regime changes (**Bullish** or **Bearish**)
#
# 3. Finally, we will cross-analyze a market's sector weightings with our picked stock's sector to gauge which one corresponds best to it.

# %%
# get sector weightings for SPY, EWJ and EWL
def sector_weights_etf():
    etfs = ['SPY', 'EWJ', 'EWL']
    
    rows = []

    for symbol in etfs:
        t = yf.Ticker(symbol)
        
        # FundsData object (for ETFs / mutual funds)
        fd = t.get_funds_data()

        if fd is None:
            print(f"No funds data for {symbol}")
            continue

        # sector_weightings is a dict: {sector_key: weight_float}
        sw = fd.sector_weightings
        if not sw:
            print(f"No sector weightings for {symbol}")
            continue

        for sector, weight in sw.items():
            rows.append(
                {
                    "ticker": symbol,
                    "sector": sector,     # e.g. 'technology', 'financial_services'
                    "weight": weight,     # e.g. 0.3562 = 35.62%
                }
            )

    sector_weights_long = pd.DataFrame(rows)
    sector_weights_wide = round(sector_weights_long.pivot(index="sector", columns="ticker", values="weight").sort_index()*100, 2)

    return sector_weights_wide

# %%
def market_trends():
    etfs = ['SPY', 'EWJ', 'EWL']

    # get 5Y of closing prices and volumes for ETFs
    df = yf.download(etfs, period="5Y")[['Close','Volume']]

    df_flat = df.copy()
    df_flat.columns = [f"{ticker}_{field}" for field, ticker in df_flat.columns]

    # plot the ETFs

    # Keep only *_Close columns
    close_cols = [c for c in df_flat.columns if c.endswith("_Close")]
    close = df_flat[close_cols]

    min_vals = close.min()
    max_vals = close.max()
    scaled_01 = (close - min_vals) / (max_vals - min_vals)
    scaled_01.columns = [c.replace("_Close", "") for c in scaled_01.columns]

    plt.figure(figsize=(10, 5))
    scaled_01.plot(ax=plt.gca())
    plt.title("SPY vs EWJ vs EWL (Min–Max Scaled, 0–1)")
    plt.xlabel("Date")
    plt.ylabel("Scaled price (0–1)")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    return df_flat

# %%
market_trends()
# Out:
# [*********************100%***********************]  3 of 3 completed
#             EWJ_Close  EWL_Close   SPY_Close  EWJ_Volume  EWL_Volume  \
# Date
# 2020-11-30  58.967861  38.489941  337.534302    13251100     1326100
# 2020-12-01  60.176712  39.123447  341.226105    14044600     2962300
# 2020-12-02  60.075966  39.087250  341.943970     6772000      976900
# 2020-12-03  60.222500  38.924339  341.850708     4483900      793800
# 2020-12-04  60.497231  39.141548  344.796631     7600500      865600
# ...               ...        ...         ...         ...         ...
# 2025-11-21  81.190002  56.689999  659.030029     8907800      719600
# 2025-11-24  81.739998  56.389999  668.729980     3799400      503700
# 2025-11-25  81.919998  57.259998  675.020020     5197000      625800
# 2025-11-26  83.260002  57.549999  679.679993     3711400      233200
# 2025-11-28  83.010002  57.820000  683.390015     2711800      256800
#
#             SPY_Volume
# Date
# 2020-11-30    83872700
# 2020-12-01    74231400
# 2020-12-02    45927000
# 2020-12-03    62882000
# 2020-12-04    50749900
# ...                ...
# 2025-11-21   123956200
# 2025-11-24    80437900
# 2025-11-25    81077100
# 2025-11-26    71879600
# 2025-11-28    49212000
#
# [1256 rows x 6 columns]

# %%
revolut = ['RIOT','AIRO','WULF']
for i in revolut:
    moving_average_crossover(i, 50, 200)
    mean_reversion(i, 50)
    momentum(i)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
